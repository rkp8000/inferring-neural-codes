# %% [markdown]
# # Predict female behav vars from top PCs of surrogate neural population activity

# %%
# %matplotlib inline
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
from sklearn import linear_model
from sklearn.decomposition import PCA
import sys
import warnings; warnings.filterwarnings("ignore")

from disp import set_plot
from my_torch import skl_fit_ridge

cc = np.concatenate

STRAINS = ['NM91', 'ZH23']
STRAIN_KEY = '_'.join(STRAINS).lower()

PTRAIN = .8
NSPLIT = 30

TARGS = ['CTL']
W_CTL = np.random.randn(224)/np.sqrt(224)

NRL_MDL = 'ma'

ALPHA = 10

NSPLIT_SAVE_Y_HAT = 3

NPCS = np.array([1, 5, 10, 20, 30, 50, 100, 224]) #

ZSCORE = True

# %%
PFX_BHV = f'data/simple/behav_xtd/behav_xtd'

FSTRAIN = 'data/simple/strains.csv'
MSTRAINS = [(pd.read_csv(FSTRAIN)['STRAIN'] == strain) for strain in STRAINS]
MSTRAIN = np.any(MSTRAINS, axis=0)
ISTRAIN = MSTRAIN.nonzero()[0]

NTR = len(ISTRAIN)
NTRAIN = int(round(PTRAIN*NTR))

# %%
frs = []
y_ctls = []
tr_lens = []

pfx_pre_pca = f'data/simple/mlv/neur_basic/baker_{NRL_MDL}/mlv_baker_{NRL_MDL}'

dfs_tr = [np.load(f'{pfx_pre_pca}_tr_{itr}.npy', allow_pickle=True)[0]['df'] for itr in ISTRAIN]
     
for itr, df_tr in zip(ISTRAIN, dfs_tr):
    r_cols = [f'R_{ir}' for ir in range(224)]
    frs.append(np.array(df_tr[r_cols]))
    tr_lens.append(len(df_tr))
    
    y_ctl = np.array(df_tr[r_cols])@W_CTL + 5*np.random.randn(len(df_tr))
    y_ctls.append(y_ctl)
    
frs = cc(frs, axis=0)

if ZSCORE:
    fr_mn = frs.mean(axis=0)
    fr_sd = frs.std(axis=0)
    
    frs = frs - fr_mn
    frs = frs / fr_sd

if not ZSCORE:
    pfx_nrl = f'data/simple/mlv/neur_basic/baker_{NRL_MDL}_pca_ctl/mlv_baker_{NRL_MDL}_pca_ctl'
else:
    pfx_nrl = f'data/simple/mlv/neur_basic/baker_{NRL_MDL}_zpca_ctl/mlv_baker_{NRL_MDL}_zpca_ctl'

# %%
for npc in NPCS:
    print(f'{npc} PCs...')
    # perform PCA on neural data, saving only npc components
    pca = PCA(n_components=npc)
    frs_reduced = pca.fit_transform(frs)
    
    for cpc, expl_var in enumerate(pca.explained_variance_ratio_):
        print(f'Var expl by PC {cpc} = {expl_var:.4f}')
        
    # save reduced trials
    it_starts = cc([[0], np.cumsum(tr_lens)[:-1]])
    it_stops = np.cumsum(tr_lens)
    
    for it_start, it_stop, itr, df_tr, y_ctl in zip(it_starts, it_stops, ISTRAIN, dfs_tr, y_ctls):
        df_tr_pca = df_tr[[col for col in df_tr.columns if not col.startswith('R_')]]
        # add PC cols
        for cpc in range(npc):
            df_tr_pca[f'PC_{cpc}'] = frs_reduced[it_start:it_stop, cpc]
            
        # add control behavior
        df_tr_pca['CTL'] = y_ctl.copy()
            
        # save trial
        np.save(f'{pfx_nrl}_tr_{itr}.npy', np.array([{'df': df_tr_pca}]))
        
    cols_use = [f'PC_{cpc}' for cpc in range(npc)]
    
    fsave = f'data/simple/mlv/neur_basic/baker_{NRL_MDL}_zpca_ctl/baker_{NRL_MDL}_{STRAIN_KEY}_ctl_ridge_alpha_{ALPHA}_{npc}_zpc.npy'
    
    # fit regression models
    rslts = skl_fit_ridge(
        pfxs=[pfx_nrl, PFX_BHV],
        cols_x=cols_use,
        targs=TARGS,
        itr_all=ISTRAIN, 
        ntrain=NTRAIN,
        nsplit=NSPLIT,
        return_y=np.arange(NSPLIT_SAVE_Y_HAT),
        alpha=ALPHA)

    # save r2, weights, and example predictions
    save_data = {
        'r2_train': {targ: np.array([rslt.r2_train[targ] for rslt in rslts]) for targ in TARGS},
        'r2_test': {targ: np.array([rslt.r2_test[targ] for rslt in rslts]) for targ in TARGS},
        
        'w': {targ: np.array([rslt.w[targ] for rslt in rslts]) for targ in TARGS},
        
        'ys_train': {targ: [rslt.ys_train[targ] for rslt in rslts if rslt.ys_train] for targ in TARGS},
        'ys_test': {targ: [rslt.ys_test[targ] for rslt in rslts if rslt.ys_train] for targ in TARGS},
        
        'y_hats_train': {targ: [rslt.y_hats_train[targ] for rslt in rslts if rslt.ys_train] for targ in TARGS},
        'y_hats_test': {targ: [rslt.y_hats_test[targ] for rslt in rslts if rslt.ys_train] for targ in TARGS},
        
        'targs': TARGS,
        'alpha': ALPHA,
        
        'ntr': NTR,
        'ntrain': NTRAIN,
        'nsplit': NSPLIT,
        
        'nr': len(cols_use)
    }

    print('')
    for targ in TARGS:
        r2_test = save_data['r2_test'][targ]
        print(f'<{targ} R2> = {np.mean(r2_test)}')
        
    print('')
    
    np.save(fsave, np.array([save_data]))
# Out:
# 1 PCs...
# Var expl by PC 0 = 0.7275
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.04355992512989202
#
# 5 PCs...
# Var expl by PC 0 = 0.7275
# Var expl by PC 1 = 0.1202
# Var expl by PC 2 = 0.0825
# Var expl by PC 3 = 0.0267
# Var expl by PC 4 = 0.0168
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.05735818514759329
#
# 10 PCs...
# Var expl by PC 0 = 0.7275
# Var expl by PC 1 = 0.1202
# Var expl by PC 2 = 0.0825
# Var expl by PC 3 = 0.0267
# Var expl by PC 4 = 0.0168
# Var expl by PC 5 = 0.0074
# Var expl by PC 6 = 0.0046
# Var expl by PC 7 = 0.0037
# Var expl by PC 8 = 0.0029
# Var expl by PC 9 = 0.0017
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.058785401172794
#
# 20 PCs...
# Var expl by PC 0 = 0.7275
# Var expl by PC 1 = 0.1202
# Var expl by PC 2 = 0.0825
# Var expl by PC 3 = 0.0267
# Var expl by PC 4 = 0.0168
# Var expl by PC 5 = 0.0074
# Var expl by PC 6 = 0.0046
# Var expl by PC 7 = 0.0037
# Var expl by PC 8 = 0.0029
# Var expl by PC 9 = 0.0017
# Var expl by PC 10 = 0.0012
# Var expl by PC 11 = 0.0008
# Var expl by PC 12 = 0.0007
# Var expl by PC 13 = 0.0006
# Var expl by PC 14 = 0.0005
# Var expl by PC 15 = 0.0004
# Var expl by PC 16 = 0.0003
# Var expl by PC 17 = 0.0002
# Var expl by PC 18 = 0.0002
# Var expl by PC 19 = 0.0002
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.0595812036411701
#
# 30 PCs...
# Var expl by PC 0 = 0.7275
# Var expl by PC 1 = 0.1202
# Var expl by PC 2 = 0.0825
# Var expl by PC 3 = 0.0267
# Var expl by PC 4 = 0.0168
# Var expl by PC 5 = 0.0074
# Var expl by PC 6 = 0.0046
# Var expl by PC 7 = 0.0037
# Var expl by PC 8 = 0.0029
# Var expl by PC 9 = 0.0017
# Var expl by PC 10 = 0.0012
# Var expl by PC 11 = 0.0008
# Var expl by PC 12 = 0.0007
# Var expl by PC 13 = 0.0006
# Var expl by PC 14 = 0.0005
# Var expl by PC 15 = 0.0004
# Var expl by PC 16 = 0.0003
# Var expl by PC 17 = 0.0002
# Var expl by PC 18 = 0.0002
# Var expl by PC 19 = 0.0002
# Var expl by PC 20 = 0.0001
# Var expl by PC 21 = 0.0001
# Var expl by PC 22 = 0.0001
# Var expl by PC 23 = 0.0001
# Var expl by PC 24 = 0.0001
# Var expl by PC 25 = 0.0001
# Var expl by PC 26 = 0.0000
# Var expl by PC 27 = 0.0000
# Var expl by PC 28 = 0.0000
# Var expl by PC 29 = 0.0000
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.0596519546190501
#
# 50 PCs...
# Var expl by PC 0 = 0.7275
# Var expl by PC 1 = 0.1202
# Var expl by PC 2 = 0.0825
# Var expl by PC 3 = 0.0267
# Var expl by PC 4 = 0.0168
# Var expl by PC 5 = 0.0074
# Var expl by PC 6 = 0.0046
# Var expl by PC 7 = 0.0037
# Var expl by PC 8 = 0.0029
# Var expl by PC 9 = 0.0017
# Var expl by PC 10 = 0.0012
# Var expl by PC 11 = 0.0008
# Var expl by PC 12 = 0.0007
# Var expl by PC 13 = 0.0006
# Var expl by PC 14 = 0.0005
# Var expl by PC 15 = 0.0004
# Var expl by PC 16 = 0.0003
# Var expl by PC 17 = 0.0002
# Var expl by PC 18 = 0.0002
# Var expl by PC 19 = 0.0002
# Var expl by PC 20 = 0.0001
# Var expl by PC 21 = 0.0001
# Var expl by PC 22 = 0.0001
# Var expl by PC 23 = 0.0001
# Var expl by PC 24 = 0.0001
# Var expl by PC 25 = 0.0001
# Var expl by PC 26 = 0.0000
# Var expl by PC 27 = 0.0000
# Var expl by PC 28 = 0.0000
# Var expl by PC 29 = 0.0000
# Var expl by PC 30 = 0.0000
# Var expl by PC 31 = 0.0000
# Var expl by PC 32 = 0.0000
# Var expl by PC 33 = 0.0000
# Var expl by PC 34 = 0.0000
# Var expl by PC 35 = 0.0000
# Var expl by PC 36 = 0.0000
# Var expl by PC 37 = 0.0000
# Var expl by PC 38 = 0.0000
# Var expl by PC 39 = 0.0000
# Var expl by PC 40 = 0.0000
# Var expl by PC 41 = 0.0000
# Var expl by PC 42 = 0.0000
# Var expl by PC 43 = 0.0000
# Var expl by PC 44 = 0.0000
# Var expl by PC 45 = 0.0000
# Var expl by PC 46 = 0.0000
# Var expl by PC 47 = 0.0000
# Var expl by PC 48 = 0.0000
# Var expl by PC 49 = 0.0000
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.059666336044412585
#
# 100 PCs...
# Var expl by PC 0 = 0.7275
# Var expl by PC 1 = 0.1202
# Var expl by PC 2 = 0.0825
# Var expl by PC 3 = 0.0267
# Var expl by PC 4 = 0.0168
# Var expl by PC 5 = 0.0074
# Var expl by PC 6 = 0.0046
# Var expl by PC 7 = 0.0037
# Var expl by PC 8 = 0.0029
# Var expl by PC 9 = 0.0017
# Var expl by PC 10 = 0.0012
# Var expl by PC 11 = 0.0008
# Var expl by PC 12 = 0.0007
# Var expl by PC 13 = 0.0006
# Var expl by PC 14 = 0.0005
# Var expl by PC 15 = 0.0004
# Var expl by PC 16 = 0.0003
# Var expl by PC 17 = 0.0002
# Var expl by PC 18 = 0.0002
# Var expl by PC 19 = 0.0002
# Var expl by PC 20 = 0.0001
# Var expl by PC 21 = 0.0001
# Var expl by PC 22 = 0.0001
# Var expl by PC 23 = 0.0001
# Var expl by PC 24 = 0.0001
# Var expl by PC 25 = 0.0001
# Var expl by PC 26 = 0.0000
# Var expl by PC 27 = 0.0000
# Var expl by PC 28 = 0.0000
# Var expl by PC 29 = 0.0000
# Var expl by PC 30 = 0.0000
# Var expl by PC 31 = 0.0000
# Var expl by PC 32 = 0.0000
# Var expl by PC 33 = 0.0000
# Var expl by PC 34 = 0.0000
# Var expl by PC 35 = 0.0000
# Var expl by PC 36 = 0.0000
# Var expl by PC 37 = 0.0000
# Var expl by PC 38 = 0.0000
# Var expl by PC 39 = 0.0000
# Var expl by PC 40 = 0.0000
# Var expl by PC 41 = 0.0000
# Var expl by PC 42 = 0.0000
# Var expl by PC 43 = 0.0000
# Var expl by PC 44 = 0.0000
# Var expl by PC 45 = 0.0000
# Var expl by PC 46 = 0.0000
# Var expl by PC 47 = 0.0000
# Var expl by PC 48 = 0.0000
# Var expl by PC 49 = 0.0000
# Var expl by PC 50 = 0.0000
# Var expl by PC 51 = 0.0000
# Var expl by PC 52 = 0.0000
# Var expl by PC 53 = 0.0000
# Var expl by PC 54 = 0.0000
# Var expl by PC 55 = 0.0000
# Var expl by PC 56 = 0.0000
# Var expl by PC 57 = 0.0000
# Var expl by PC 58 = 0.0000
# Var expl by PC 59 = 0.0000
# Var expl by PC 60 = 0.0000
# Var expl by PC 61 = 0.0000
# Var expl by PC 62 = 0.0000
# Var expl by PC 63 = 0.0000
# Var expl by PC 64 = 0.0000
# Var expl by PC 65 = 0.0000
# Var expl by PC 66 = 0.0000
# Var expl by PC 67 = 0.0000
# Var expl by PC 68 = 0.0000
# Var expl by PC 69 = 0.0000
# Var expl by PC 70 = 0.0000
# Var expl by PC 71 = 0.0000
# Var expl by PC 72 = 0.0000
# Var expl by PC 73 = 0.0000
# Var expl by PC 74 = 0.0000
# Var expl by PC 75 = 0.0000
# Var expl by PC 76 = 0.0000
# Var expl by PC 77 = 0.0000
# Var expl by PC 78 = 0.0000
# Var expl by PC 79 = 0.0000
# Var expl by PC 80 = 0.0000
# Var expl by PC 81 = 0.0000
# Var expl by PC 82 = 0.0000
# Var expl by PC 83 = 0.0000
# Var expl by PC 84 = 0.0000
# Var expl by PC 85 = 0.0000
# Var expl by PC 86 = 0.0000
# Var expl by PC 87 = 0.0000
# Var expl by PC 88 = 0.0000
# Var expl by PC 89 = 0.0000
# Var expl by PC 90 = 0.0000
# Var expl by PC 91 = 0.0000
# Var expl by PC 92 = 0.0000
# Var expl by PC 93 = 0.0000
# Var expl by PC 94 = 0.0000
# Var expl by PC 95 = 0.0000
# Var expl by PC 96 = 0.0000
# Var expl by PC 97 = 0.0000
# Var expl by PC 98 = 0.0000
# Var expl by PC 99 = 0.0000
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.05964221354095289
#
# 224 PCs...
# Var expl by PC 0 = 0.7275
# Var expl by PC 1 = 0.1202
# Var expl by PC 2 = 0.0825
# Var expl by PC 3 = 0.0267
# Var expl by PC 4 = 0.0168
# Var expl by PC 5 = 0.0074
# Var expl by PC 6 = 0.0046
# Var expl by PC 7 = 0.0037
# Var expl by PC 8 = 0.0029
# Var expl by PC 9 = 0.0017
# Var expl by PC 10 = 0.0012
# Var expl by PC 11 = 0.0008
# Var expl by PC 12 = 0.0007
# Var expl by PC 13 = 0.0006
# Var expl by PC 14 = 0.0005
# Var expl by PC 15 = 0.0004
# Var expl by PC 16 = 0.0003
# Var expl by PC 17 = 0.0002
# Var expl by PC 18 = 0.0002
# Var expl by PC 19 = 0.0002
# Var expl by PC 20 = 0.0001
# Var expl by PC 21 = 0.0001
# Var expl by PC 22 = 0.0001
# Var expl by PC 23 = 0.0001
# Var expl by PC 24 = 0.0001
# Var expl by PC 25 = 0.0001
# Var expl by PC 26 = 0.0000
# Var expl by PC 27 = 0.0000
# Var expl by PC 28 = 0.0000
# Var expl by PC 29 = 0.0000
# Var expl by PC 30 = 0.0000
# Var expl by PC 31 = 0.0000
# Var expl by PC 32 = 0.0000
# Var expl by PC 33 = 0.0000
# Var expl by PC 34 = 0.0000
# Var expl by PC 35 = 0.0000
# Var expl by PC 36 = 0.0000
# Var expl by PC 37 = 0.0000
# Var expl by PC 38 = 0.0000
# Var expl by PC 39 = 0.0000
# Var expl by PC 40 = 0.0000
# Var expl by PC 41 = 0.0000
# Var expl by PC 42 = 0.0000
# Var expl by PC 43 = 0.0000
# Var expl by PC 44 = 0.0000
# Var expl by PC 45 = 0.0000
# Var expl by PC 46 = 0.0000
# Var expl by PC 47 = 0.0000
# Var expl by PC 48 = 0.0000
# Var expl by PC 49 = 0.0000
# Var expl by PC 50 = 0.0000
# Var expl by PC 51 = 0.0000
# Var expl by PC 52 = 0.0000
# Var expl by PC 53 = 0.0000
# Var expl by PC 54 = 0.0000
# Var expl by PC 55 = 0.0000
# Var expl by PC 56 = 0.0000
# Var expl by PC 57 = 0.0000
# Var expl by PC 58 = 0.0000
# Var expl by PC 59 = 0.0000
# Var expl by PC 60 = 0.0000
# Var expl by PC 61 = 0.0000
# Var expl by PC 62 = 0.0000
# Var expl by PC 63 = 0.0000
# Var expl by PC 64 = 0.0000
# Var expl by PC 65 = 0.0000
# Var expl by PC 66 = 0.0000
# Var expl by PC 67 = 0.0000
# Var expl by PC 68 = 0.0000
# Var expl by PC 69 = 0.0000
# Var expl by PC 70 = 0.0000
# Var expl by PC 71 = 0.0000
# Var expl by PC 72 = 0.0000
# Var expl by PC 73 = 0.0000
# Var expl by PC 74 = 0.0000
# Var expl by PC 75 = 0.0000
# Var expl by PC 76 = 0.0000
# Var expl by PC 77 = 0.0000
# Var expl by PC 78 = 0.0000
# Var expl by PC 79 = 0.0000
# Var expl by PC 80 = 0.0000
# Var expl by PC 81 = 0.0000
# Var expl by PC 82 = 0.0000
# Var expl by PC 83 = 0.0000
# Var expl by PC 84 = 0.0000
# Var expl by PC 85 = 0.0000
# Var expl by PC 86 = 0.0000
# Var expl by PC 87 = 0.0000
# Var expl by PC 88 = 0.0000
# Var expl by PC 89 = 0.0000
# Var expl by PC 90 = 0.0000
# Var expl by PC 91 = 0.0000
# Var expl by PC 92 = 0.0000
# Var expl by PC 93 = 0.0000
# Var expl by PC 94 = 0.0000
# Var expl by PC 95 = 0.0000
# Var expl by PC 96 = 0.0000
# Var expl by PC 97 = 0.0000
# Var expl by PC 98 = 0.0000
# Var expl by PC 99 = 0.0000
# Var expl by PC 100 = 0.0000
# Var expl by PC 101 = 0.0000
# Var expl by PC 102 = 0.0000
# Var expl by PC 103 = 0.0000
# Var expl by PC 104 = 0.0000
# Var expl by PC 105 = 0.0000
# Var expl by PC 106 = 0.0000
# Var expl by PC 107 = 0.0000
# Var expl by PC 108 = 0.0000
# Var expl by PC 109 = 0.0000
# Var expl by PC 110 = 0.0000
# Var expl by PC 111 = 0.0000
# Var expl by PC 112 = 0.0000
# Var expl by PC 113 = 0.0000
# Var expl by PC 114 = 0.0000
# Var expl by PC 115 = 0.0000
# Var expl by PC 116 = 0.0000
# Var expl by PC 117 = 0.0000
# Var expl by PC 118 = 0.0000
# Var expl by PC 119 = 0.0000
# Var expl by PC 120 = 0.0000
# Var expl by PC 121 = 0.0000
# Var expl by PC 122 = 0.0000
# Var expl by PC 123 = 0.0000
# Var expl by PC 124 = 0.0000
# Var expl by PC 125 = 0.0000
# Var expl by PC 126 = 0.0000
# Var expl by PC 127 = 0.0000
# Var expl by PC 128 = 0.0000
# Var expl by PC 129 = 0.0000
# Var expl by PC 130 = 0.0000
# Var expl by PC 131 = 0.0000
# Var expl by PC 132 = 0.0000
# Var expl by PC 133 = 0.0000
# Var expl by PC 134 = 0.0000
# Var expl by PC 135 = 0.0000
# Var expl by PC 136 = 0.0000
# Var expl by PC 137 = 0.0000
# Var expl by PC 138 = 0.0000
# Var expl by PC 139 = 0.0000
# Var expl by PC 140 = 0.0000
# Var expl by PC 141 = 0.0000
# Var expl by PC 142 = 0.0000
# Var expl by PC 143 = 0.0000
# Var expl by PC 144 = 0.0000
# Var expl by PC 145 = 0.0000
# Var expl by PC 146 = 0.0000
# Var expl by PC 147 = 0.0000
# Var expl by PC 148 = 0.0000
# Var expl by PC 149 = 0.0000
# Var expl by PC 150 = 0.0000
# Var expl by PC 151 = 0.0000
# Var expl by PC 152 = 0.0000
# Var expl by PC 153 = 0.0000
# Var expl by PC 154 = 0.0000
# Var expl by PC 155 = 0.0000
# Var expl by PC 156 = 0.0000
# Var expl by PC 157 = 0.0000
# Var expl by PC 158 = 0.0000
# Var expl by PC 159 = 0.0000
# Var expl by PC 160 = 0.0000
# Var expl by PC 161 = 0.0000
# Var expl by PC 162 = 0.0000
# Var expl by PC 163 = 0.0000
# Var expl by PC 164 = 0.0000
# Var expl by PC 165 = 0.0000
# Var expl by PC 166 = 0.0000
# Var expl by PC 167 = 0.0000
# Var expl by PC 168 = 0.0000
# Var expl by PC 169 = 0.0000
# Var expl by PC 170 = 0.0000
# Var expl by PC 171 = 0.0000
# Var expl by PC 172 = 0.0000
# Var expl by PC 173 = 0.0000
# Var expl by PC 174 = 0.0000
# Var expl by PC 175 = 0.0000
# Var expl by PC 176 = 0.0000
# Var expl by PC 177 = 0.0000
# Var expl by PC 178 = 0.0000
# Var expl by PC 179 = 0.0000
# Var expl by PC 180 = 0.0000
# Var expl by PC 181 = 0.0000
# Var expl by PC 182 = 0.0000
# Var expl by PC 183 = 0.0000
# Var expl by PC 184 = 0.0000
# Var expl by PC 185 = 0.0000
# Var expl by PC 186 = 0.0000
# Var expl by PC 187 = 0.0000
# Var expl by PC 188 = 0.0000
# Var expl by PC 189 = 0.0000
# Var expl by PC 190 = 0.0000
# Var expl by PC 191 = 0.0000
# Var expl by PC 192 = 0.0000
# Var expl by PC 193 = 0.0000
# Var expl by PC 194 = 0.0000
# Var expl by PC 195 = 0.0000
# Var expl by PC 196 = 0.0000
# Var expl by PC 197 = 0.0000
# Var expl by PC 198 = 0.0000
# Var expl by PC 199 = 0.0000
# Var expl by PC 200 = 0.0000
# Var expl by PC 201 = 0.0000
# Var expl by PC 202 = 0.0000
# Var expl by PC 203 = 0.0000
# Var expl by PC 204 = 0.0000
# Var expl by PC 205 = 0.0000
# Var expl by PC 206 = 0.0000
# Var expl by PC 207 = 0.0000
# Var expl by PC 208 = 0.0000
# Var expl by PC 209 = 0.0000
# Var expl by PC 210 = 0.0000
# Var expl by PC 211 = 0.0000
# Var expl by PC 212 = 0.0000
# Var expl by PC 213 = 0.0000
# Var expl by PC 214 = 0.0000
# Var expl by PC 215 = 0.0000
# Var expl by PC 216 = 0.0000
# Var expl by PC 217 = 0.0000
# Var expl by PC 218 = 0.0000
# Var expl by PC 219 = 0.0000
# Var expl by PC 220 = 0.0000
# Var expl by PC 221 = 0.0000
# Var expl by PC 222 = 0.0000
# Var expl by PC 223 = 0.0000
# Loading...
#
# Split 0
# Split 1
# Split 2
# Split 3
# Split 4
# Split 5
# Split 6
# Split 7
# Split 8
# Split 9
# Split 10
# Split 11
# Split 12
# Split 13
# Split 14
# Split 15
# Split 16
# Split 17
# Split 18
# Split 19
# Split 20
# Split 21
# Split 22
# Split 23
# Split 24
# Split 25
# Split 26
# Split 27
# Split 28
# Split 29
# <CTL R2> = 0.0596420753604766
