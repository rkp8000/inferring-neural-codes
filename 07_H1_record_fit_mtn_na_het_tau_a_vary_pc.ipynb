# %% [markdown]
# # Predict female walking speed from top PCs of simulated NA ppln with fixed slow integration time constant

# %%
# %matplotlib inline
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from scipy import signal, stats
from sklearn import linear_model, decomposition
import sys
import warnings; warnings.filterwarnings("ignore")

from aux import get_seg, rand_string
from disp import set_plot
from my_torch import skl_fit_ridge
from my_stats import nanpearsonr

from record_0_main import smlt_ma

cc = np.concatenate

FPS = 30.03  # sampling rate of behavioral data
DT = 1/FPS

STRAINS = ['NM91', 'ZH23']
STRAIN_KEY = '_'.join(STRAINS).lower()

PTRAIN = .8
NSPLIT = 30

TARG_BHV = 'MTN'
TWDWS = [.03, 1, 60]
TARGS = [f'{TARG_BHV}_MN_{twdw}' for twdw in TWDWS]

ALPHA = 10

# %%
PFX_BHV = f'data/simple/behav_xtd/behav_xtd'
PFX_NRL = f'data/simple/mlv/ma_het_tau_a_vary_pc/temp_nrl/temp_ma_n_vary_pc_{rand_string(8)}'

MASK_PFX = f'data/simple/masks/mask'

FSTRAIN = 'data/simple/strains.csv'
MSTRAINS = [(pd.read_csv(FSTRAIN)['STRAIN'] == strain) for strain in STRAINS]
MSTRAIN = np.any(MSTRAINS, axis=0)
ISTRAIN = MSTRAIN.nonzero()[0]

NTR = len(ISTRAIN)
NTRAIN = int(round(PTRAIN*NTR))

# %% [markdown]
# Load behavioral data from Coen et al 2014

# %%
df_behav = pd.read_csv('data/simple/c_song_f_behav.csv')
df_behav
# Out:
#           ID  FRAME           T  Q  S  P  F    FFV     FFA    FLS    FRS  \
# 0          0      0    0.000000  1  0  0  0  0.231  0.0000  0.159  0.077
# 1          0      1    0.033300  1  0  0  0  0.314  0.0385  0.025  0.044
# 2          0      2    0.066600  1  0  0  0  0.308  0.0025  0.029  0.011
# 3          0      3    0.099900  1  0  0  0  0.319  0.0020  0.016  0.016
# 4          0      4    0.133200  1  0  0  0  0.312 -0.0315  0.030  0.002
# ...      ...    ...         ... .. .. .. ..    ...     ...    ...    ...
# 4978565  275  27100  902.430902  1  0  0  0  0.217  0.0280  0.029  0.058
# 4978566  275  27101  902.464202  1  0  0  0  0.210 -0.1045  0.138  0.322
# 4978567  275  27102  902.497502  1  0  0  0  0.008 -0.0910  0.034  0.260
# 4978568  275  27103  902.530803  1  0  0  0  0.028  0.0695  0.010  0.090
# 4978569  275  27104  902.564103  1  0  0  0  0.147  0.0000  0.065  0.001
#
#              FMFV      FMLS
# 0       -0.058526  0.274257
# 1        0.100623  0.298490
# 2        0.147629  0.271865
# 3        0.091174  0.306112
# 4        0.065871  0.306439
# ...           ...       ...
# 4978565 -0.171418  0.136184
# 4978566  0.032522  0.249171
# 4978567  0.033202  0.010844
# 4978568  0.012059  0.027177
# 4978569  0.089547  0.133474
#
# [4978570 rows x 13 columns]

# %%
# split big df into dfs for individual trials
n_tr = np.max(df_behav.ID) + 1
dfs_tr = [df_behav[df_behav.ID == i] for i in ISTRAIN]

df_behav = None

# %%
# function for recording surrogate neural activity and predicting behavior
def record_fit(tau_rs, tau_as, x_ss, x_ps, npc):
    
    # record data
    sys.stdout.write('R')
    
    rs_all = []
    
    for itr, df_tr in zip(ISTRAIN, dfs_tr):

        i_s = np.array(df_tr['S']).astype(float)
        i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)

        # simulate population response
        params = {'TAU_R': tau_rs, 'TAU_A': tau_as, 'X_S': x_ss, 'X_P': x_ps}
        rs = smlt_ma(i_s, i_p, params, DT)

        rs_all.append(rs.copy())
    
    # run PCA on concatenated responses
    pca = decomposition.PCA(n_components=npc).fit(cc(rs_all, axis=0))
    
    # store responses projected onto top pcs in dataframe
    pc_cols = [f'PC_{cpc}' for cpc in range(npc)]
    
    for itr, df_tr, rs in zip(ISTRAIN, dfs_tr, rs_all):
        df_tr_nrl = df_tr.copy()
        df_tr_nrl[pc_cols] = pca.transform(rs)
        
        np.save(f'{PFX_NRL}_tr_{itr}.npy', np.array([{'df': df_tr_nrl}]))
        
    sys.stdout.write('F')
    # fit neural -> behav regression model
    rslts = skl_fit_ridge(
        pfxs=[PFX_NRL, PFX_BHV],
        cols_x=pc_cols,
        targs=TARGS,
        itr_all=ISTRAIN,
        ntrain=NTRAIN,
        nsplit=NSPLIT,
        alpha=ALPHA,
        mask_pfx=MASK_PFX,
        verbose='dots')
    
    r2_train_mns = {targ: np.mean([rslt.r2_train[targ] for rslt in rslts]) for targ in TARGS}
    r2_test_mns = {targ: np.mean([rslt.r2_test[targ] for rslt in rslts]) for targ in TARGS}
    
    r2_train_sds = {targ: np.std([rslt.r2_train[targ] for rslt in rslts]) for targ in TARGS}
    r2_test_sds = {targ: np.std([rslt.r2_test[targ] for rslt in rslts]) for targ in TARGS}
    
    ws = {targ: np.array([rslt.w[targ] for rslt in rslts]) for targ in TARGS}
    
    pcs = pca.components_
    
    return r2_train_mns, r2_test_mns, r2_train_sds, r2_test_sds, ws, pcs

# %% [markdown]
# # Sweep over number of PCs kept from fast-adapt, slow-integrate MA ppln

# %%
N = 20
NPCS = np.arange(1, N+1)

NPPLN = 30

r2_trains = []
r2_tests = []

rtau_r = [120, 120]
rtau_a = [.1, 2]

r2_trains_all = {targ: [] for targ in TARGS}
r2_tests_all = {targ: [] for targ in TARGS}

for npc in NPCS:
    
    r2_trains = {targ: [] for targ in TARGS}
    r2_tests = {targ: [] for targ in TARGS}
    ws_all = {targ: [] for targ in TARGS}
    pcs_all = []
    
    tau_rs_all_npc = []
    tau_as_all_npc = []
    x_ss_all_npc = []
    x_ps_all_npc = []
    
    for cppln in range(NPPLN):
        sys.stdout.write(f'NPC={npc},PPLN={cppln}:')
        np.random.seed(None)
        tau_rs = np.random.uniform(*rtau_r, N)
        tau_as = np.random.uniform(*rtau_a, N)
        x_ss = np.random.uniform(0, 1, N)
        x_ps = 1 - x_ss
        
        r2_train_mns, r2_test_mns, _, _, ws, pcs = record_fit(tau_rs, tau_as, x_ss, x_ps, npc=npc)
        
        for targ in TARGS:
            r2_trains[targ].append(r2_train_mns[targ])
            r2_tests[targ].append(r2_test_mns[targ])
            ws_all[targ].append(ws[targ])
            
        pcs_all.append(pcs)
            
        tau_rs_all_npc.append(tau_rs)
        tau_as_all_npc.append(tau_as)
        x_ss_all_npc.append(x_ss)
        x_ps_all_npc.append(x_ps)
        
        print('')
            
    for targ in TARGS:
        r2_trains_all[targ].append(r2_trains[targ])
        r2_tests_all[targ].append(r2_tests[targ])
        
    # save training and test r2s and corresponding params
    np.save(f'data/simple/mlv/ma_het_tau_a_vary_pc/ma_het_tau_a_npc_{npc}.npy', np.array([{
        'R2_TRAINS': r2_trains, 'R2_TESTS': r2_tests, 'TAU_RS_ALL': tau_rs_all_npc, 'TAU_AS_ALL': tau_as_all_npc, 'X_SS_ALL': x_ss_all_npc, 'X_PS_ALL': x_ps_all_npc,
        'WS': ws_all, 'PCS': pcs_all,
    }]))
    
    print('')
# Out:
# NPC=1,PPLN=0:RF..............................
# NPC=1,PPLN=1:RF..............................
# NPC=1,PPLN=2:RF..............................
# NPC=1,PPLN=3:RF..............................
# NPC=1,PPLN=4:RF..............................
# NPC=1,PPLN=5:RF..............................
# NPC=1,PPLN=6:RF..............................
# NPC=1,PPLN=7:RF..............................
# NPC=1,PPLN=8:RF..............................
# NPC=1,PPLN=9:RF..............................
# NPC=1,PPLN=10:RF..............................
# NPC=1,PPLN=11:RF..............................
# NPC=1,PPLN=12:RF..............................
# NPC=1,PPLN=13:RF..............................
# NPC=1,PPLN=14:RF..............................
# NPC=1,PPLN=15:RF..............................
# NPC=1,PPLN=16:RF..............................
# NPC=1,PPLN=17:RF..............................
# NPC=1,PPLN=18:RF..............................
# NPC=1,PPLN=19:RF..............................
# NPC=1,PPLN=20:RF..............................
# NPC=1,PPLN=21:RF..............................
# NPC=1,PPLN=22:RF..............................
# NPC=1,PPLN=23:RF..............................
# NPC=1,PPLN=24:RF..............................
# NPC=1,PPLN=25:RF..............................
# NPC=1,PPLN=26:RF..............................
# NPC=1,PPLN=27:RF..............................
# NPC=1,PPLN=28:RF..............................
# NPC=1,PPLN=29:RF..............................
#
# NPC=2,PPLN=0:RF..............................
# NPC=2,PPLN=1:RF..............................
# NPC=2,PPLN=2:RF..............................
# NPC=2,PPLN=3:RF..............................
# NPC=2,PPLN=4:RF..............................
# NPC=2,PPLN=5:RF..............................
# NPC=2,PPLN=6:RF..............................
# NPC=2,PPLN=7:RF..............................
# NPC=2,PPLN=8:RF..............................
# NPC=2,PPLN=9:RF..............................
# NPC=2,PPLN=10:RF..............................
# NPC=2,PPLN=11:RF..............................
# NPC=2,PPLN=12:RF..............................
# NPC=2,PPLN=13:RF..............................
# NPC=2,PPLN=14:RF..............................
# NPC=2,PPLN=15:RF..............................
# NPC=2,PPLN=16:RF..............................
# NPC=2,PPLN=17:RF..............................
# NPC=2,PPLN=18:RF..............................
# NPC=2,PPLN=19:RF..............................
# NPC=2,PPLN=20:RF..............................
# NPC=2,PPLN=21:RF..............................
# NPC=2,PPLN=22:RF..............................
# NPC=2,PPLN=23:RF..............................
# NPC=2,PPLN=24:RF..............................
# NPC=2,PPLN=25:RF..............................
# NPC=2,PPLN=26:RF..............................
# NPC=2,PPLN=27:RF..............................
# NPC=2,PPLN=28:RF..............................
# NPC=2,PPLN=29:RF..............................
#
# NPC=3,PPLN=0:RF..............................
# NPC=3,PPLN=1:RF..............................
# NPC=3,PPLN=2:RF..............................
# NPC=3,PPLN=3:RF..............................
# NPC=3,PPLN=4:RF..............................
# NPC=3,PPLN=5:RF..............................
# NPC=3,PPLN=6:RF..............................
# NPC=3,PPLN=7:RF..............................
# NPC=3,PPLN=8:RF..............................
# NPC=3,PPLN=9:RF..............................
# NPC=3,PPLN=10:RF..............................
# NPC=3,PPLN=11:RF..............................
# NPC=3,PPLN=12:RF..............................
# NPC=3,PPLN=13:RF..............................
# NPC=3,PPLN=14:RF..............................
# NPC=3,PPLN=15:RF..............................
# NPC=3,PPLN=16:RF..............................
# NPC=3,PPLN=17:RF..............................
# NPC=3,PPLN=18:RF..............................
# NPC=3,PPLN=19:RF..............................
# NPC=3,PPLN=20:RF..............................
# NPC=3,PPLN=21:RF..............................
# NPC=3,PPLN=22:RF..............................
# NPC=3,PPLN=23:RF..............................
# NPC=3,PPLN=24:RF..............................
# NPC=3,PPLN=25:RF..............................
# NPC=3,PPLN=26:RF..............................
# NPC=3,PPLN=27:RF..............................
# NPC=3,PPLN=28:RF..............................
# NPC=3,PPLN=29:RF..............................
#
# NPC=4,PPLN=0:RF..............................
# NPC=4,PPLN=1:RF..............................
# NPC=4,PPLN=2:RF..............................
# NPC=4,PPLN=3:RF..............................
# NPC=4,PPLN=4:RF..............................
# NPC=4,PPLN=5:RF..............................
# NPC=4,PPLN=6:RF..............................
# NPC=4,PPLN=7:RF..............................
# NPC=4,PPLN=8:RF..............................
# NPC=4,PPLN=9:RF..............................
# NPC=4,PPLN=10:RF..............................
# NPC=4,PPLN=11:RF..............................
# NPC=4,PPLN=12:RF..............................
# NPC=4,PPLN=13:RF..............................
# NPC=4,PPLN=14:RF..............................
# NPC=4,PPLN=15:RF..............................
# NPC=4,PPLN=16:RF..............................
# NPC=4,PPLN=17:RF..............................
# NPC=4,PPLN=18:RF..............................
# NPC=4,PPLN=19:RF..............................
# NPC=4,PPLN=20:RF..............................
# NPC=4,PPLN=21:RF..............................
# NPC=4,PPLN=22:RF..............................
# NPC=4,PPLN=23:RF..............................
# NPC=4,PPLN=24:RF..............................
# NPC=4,PPLN=25:RF..............................
# NPC=4,PPLN=26:RF..............................
# NPC=4,PPLN=27:RF..............................
# NPC=4,PPLN=28:RF..............................
# NPC=4,PPLN=29:RF..............................
#
# NPC=5,PPLN=0:RF..............................
# NPC=5,PPLN=1:RF..............................
# NPC=5,PPLN=2:RF..............................
# NPC=5,PPLN=3:RF..............................
# NPC=5,PPLN=4:RF..............................
# NPC=5,PPLN=5:RF..............................
# NPC=5,PPLN=6:RF..............................
# NPC=5,PPLN=7:RF..............................
# NPC=5,PPLN=8:RF..............................
# NPC=5,PPLN=9:RF..............................
# NPC=5,PPLN=10:RF..............................
# NPC=5,PPLN=11:RF..............................
# NPC=5,PPLN=12:RF..............................
# NPC=5,PPLN=13:RF..............................
# NPC=5,PPLN=14:RF..............................
# NPC=5,PPLN=15:RF..............................
# NPC=5,PPLN=16:RF..............................
# NPC=5,PPLN=17:RF..............................
# NPC=5,PPLN=18:RF..............................
# NPC=5,PPLN=19:RF..............................
# NPC=5,PPLN=20:RF..............................
# NPC=5,PPLN=21:RF..............................
# NPC=5,PPLN=22:RF..............................
# NPC=5,PPLN=23:RF..............................
# NPC=5,PPLN=24:RF..............................
# NPC=5,PPLN=25:RF..............................
# NPC=5,PPLN=26:RF..............................
# NPC=5,PPLN=27:RF..............................
# NPC=5,PPLN=28:RF..............................
# NPC=5,PPLN=29:RF..............................
#
# NPC=6,PPLN=0:RF..............................
# NPC=6,PPLN=1:RF..............................
# NPC=6,PPLN=2:RF..............................
# NPC=6,PPLN=3:RF..............................
# NPC=6,PPLN=4:RF..............................
# NPC=6,PPLN=5:RF..............................
# NPC=6,PPLN=6:RF..............................
# NPC=6,PPLN=7:RF..............................
# NPC=6,PPLN=8:RF..............................
# NPC=6,PPLN=9:RF..............................
# NPC=6,PPLN=10:RF..............................
# NPC=6,PPLN=11:RF..............................
# NPC=6,PPLN=12:RF..............................
# NPC=6,PPLN=13:RF..............................
# NPC=6,PPLN=14:RF..............................
# NPC=6,PPLN=15:RF..............................
# NPC=6,PPLN=16:RF..............................
# NPC=6,PPLN=17:RF..............................
# NPC=6,PPLN=18:RF..............................
# NPC=6,PPLN=19:RF..............................
# NPC=6,PPLN=20:RF..............................
# NPC=6,PPLN=21:RF..............................
# NPC=6,PPLN=22:RF..............................
# NPC=6,PPLN=23:RF..............................
# NPC=6,PPLN=24:RF..............................
# NPC=6,PPLN=25:RF..............................
# NPC=6,PPLN=26:RF..............................
# NPC=6,PPLN=27:RF..............................
# NPC=6,PPLN=28:RF..............................
# NPC=6,PPLN=29:RF..............................
#
# NPC=7,PPLN=0:RF..............................
# NPC=7,PPLN=1:RF..............................
# NPC=7,PPLN=2:RF..............................
# NPC=7,PPLN=3:RF..............................
# NPC=7,PPLN=4:RF..............................
# NPC=7,PPLN=5:RF..............................
# NPC=7,PPLN=6:RF..............................
# NPC=7,PPLN=7:RF..............................
# NPC=7,PPLN=8:RF..............................
# NPC=7,PPLN=9:RF..............................
# NPC=7,PPLN=10:RF..............................
# NPC=7,PPLN=11:RF..............................
# NPC=7,PPLN=12:RF..............................
# NPC=7,PPLN=13:RF..............................
# NPC=7,PPLN=14:RF..............................
# NPC=7,PPLN=15:RF..............................
# NPC=7,PPLN=16:RF..............................
# NPC=7,PPLN=17:RF..............................
# NPC=7,PPLN=18:RF..............................
# NPC=7,PPLN=19:RF..............................
# NPC=7,PPLN=20:RF..............................
# NPC=7,PPLN=21:RF..............................
# NPC=7,PPLN=22:RF..............................
# NPC=7,PPLN=23:RF..............................
# NPC=7,PPLN=24:RF..............................
# NPC=7,PPLN=25:RF..............................
# NPC=7,PPLN=26:RF..............................
# NPC=7,PPLN=27:RF..............................
# NPC=7,PPLN=28:RF..............................
# NPC=7,PPLN=29:R
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a5d109a251ff> in <module>
#      33         x_ps = 1 - x_ss
#      34
# ---> 35         r2_train_mns, r2_test_mns, _, _, ws, pcs = record_fit(tau_rs, tau_as, x_ss, x_ps, npc=npc)
#      36
#      37         for targ in TARGS:
#
# <ipython-input-5-b10b4de81114> in record_fit(tau_rs, tau_as, x_ss, x_ps, npc)
#      14         # simulate population response
#      15         params = {'TAU_R': tau_rs, 'TAU_A': tau_as, 'X_S': x_ss, 'X_P': x_ps}
# ---> 16         rs = smlt_ma(i_s, i_p, params, DT)
#      17
#      18         rs_all.append(rs.copy())
#
# ~/Dropbox (Princeton)/3XPL0R/C0MMUN1C4710N_BR34KD0WN/record_0_main.py in smlt_ma(i_s, i_p, params, dt)
#      40     for ct, t_ in enumerate(t[1:], 1):
#      41         a_s += ((dt/tau_as) * (-a_s + i_s[ct]))
# ---> 42         a_p += ((dt/tau_as) * (-a_p + i_p[ct]))
#      43         dr = (dt/tau_rs) * (-rs[ct-1, :] + (1 - a_s)*x_ss*i_s[ct] + (1 - a_p)*x_ps*i_p[ct])
#      44         rs[ct, :] = rs[ct-1, :] + dr
#
# KeyboardInterrupt:
