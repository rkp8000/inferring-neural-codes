# %% [markdown]
# Create surrogate neural population responses during natural behavior trials using variations on multiplicative adaptation neural models of Baker et al data.

# %%
# %matplotlib inline
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from scipy import signal, stats
from sklearn import linear_model
import sys
import warnings; warnings.filterwarnings("ignore")

from aux import get_seg
from disp import set_font_size
from my_stats import nanpearsonr

from record import smlt_ppln_ma

cc = np.concatenate

FPS = 30.03  # sampling rate of behavioral data
DT = 1/FPS

# %% [markdown]
# Load behavioral data from Coen et al 2014

# %%
df_behav = pd.read_csv('data/simple/c_song_f_behav.csv')
df_behav
# Out:
#           ID  FRAME           T  Q  S  P  F    FFV     FFA    FLS    FRS  \
# 0          0      0    0.000000  1  0  0  0  0.231  0.0000  0.159  0.077
# 1          0      1    0.033300  1  0  0  0  0.314  0.0385  0.025  0.044
# 2          0      2    0.066600  1  0  0  0  0.308  0.0025  0.029  0.011
# 3          0      3    0.099900  1  0  0  0  0.319  0.0020  0.016  0.016
# 4          0      4    0.133200  1  0  0  0  0.312 -0.0315  0.030  0.002
# ...      ...    ...         ... .. .. .. ..    ...     ...    ...    ...
# 4978565  275  27100  902.430902  1  0  0  0  0.217  0.0280  0.029  0.058
# 4978566  275  27101  902.464202  1  0  0  0  0.210 -0.1045  0.138  0.322
# 4978567  275  27102  902.497502  1  0  0  0  0.008 -0.0910  0.034  0.260
# 4978568  275  27103  902.530803  1  0  0  0  0.028  0.0695  0.010  0.090
# 4978569  275  27104  902.564103  1  0  0  0  0.147  0.0000  0.065  0.001
#
#              FMFV      FMLS
# 0       -0.058526  0.274257
# 1        0.100623  0.298490
# 2        0.147629  0.271865
# 3        0.091174  0.306112
# 4        0.065871  0.306439
# ...           ...       ...
# 4978565 -0.171418  0.136184
# 4978566  0.032522  0.249171
# 4978567  0.033202  0.010844
# 4978568  0.012059  0.027177
# 4978569  0.089547  0.133474
#
# [4978570 rows x 13 columns]

# %%
# split big df into dfs for individual trials
n_tr = np.max(df_behav.ID) + 1
dfs_tr = [df_behav[df_behav.ID == i] for i in range(n_tr)]

tr_lens = np.array([len(df_tr) for df_tr in dfs_tr])
tr_lens_cum = cc([[0], np.cumsum(tr_lens)])

n_t_total = np.sum(tr_lens)
assert n_t_total == tr_lens_cum[-1]
df_behav = None

# %% [markdown]
# # Baseline MA model params

# %%
# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R        TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615    30.336758 -4.958290 -2.597432
# 1       True  0.117647  0.025128  3.835468    21.821295 -4.163967 -1.472075
# 2       True -0.000000  0.055962  6.017162    15.058055 -6.248007 -2.095952
# 3       True -0.000000 -0.014227  6.016828    11.820576 -5.679735 -2.118245
# 4       True -0.000000  0.019831  6.434825    55.496220 -4.415761 -2.863647
# ..       ...       ...       ...       ...          ...       ...       ...
# 219     True -0.000000  0.039119  1.799608  1440.994269 -0.049828  2.494657
# 220     True -0.000000 -0.001886  1.298841    27.643238  0.098451  2.457383
# 221     True -0.588235 -0.014702  4.151226     6.155551  8.332263  2.353217
# 222     True  0.235294 -0.095665  5.924070    90.705238  2.390705  0.604586
# 223     True -0.000000 -0.000413  3.664384    10.471628  6.416873  1.021095
#
# [224 rows x 13 columns]

# %% [markdown]
# # No adaptation
#
# All $\tau_a$ set to $\infty$.

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_nonadapt'
SAVE_PFX_MA = 'mlv_baker_ma_nonadapt'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['TAU_A'] = np.inf
df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R  TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615    inf -4.958290 -2.597432
# 1       True  0.117647  0.025128  3.835468    inf -4.163967 -1.472075
# 2       True -0.000000  0.055962  6.017162    inf -6.248007 -2.095952
# 3       True -0.000000 -0.014227  6.016828    inf -5.679735 -2.118245
# 4       True -0.000000  0.019831  6.434825    inf -4.415761 -2.863647
# ..       ...       ...       ...       ...    ...       ...       ...
# 219     True -0.000000  0.039119  1.799608    inf -0.049828  2.494657
# 220     True -0.000000 -0.001886  1.298841    inf  0.098451  2.457383
# 221     True -0.588235 -0.014702  4.151226    inf  8.332263  2.353217
# 222     True  0.235294 -0.095665  5.924070    inf  2.390705  0.604586
# 223     True -0.000000 -0.000413  3.664384    inf  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ......
# ----------------------------------------------------------------------
# KeyboardInterrupt                    Traceback (most recent call last)
# <ipython-input-7-ada99518669b> in <module>
#      10     rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
#      11
# ---> 12     df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
#      13
#      14     np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3196                 )[1]
#    3197                 self._check_setitem_copy()
# -> 3198                 self.iloc[:, indexer] = value
#    3199
#    3200     def _setitem_frame(self, key, value):
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1670
#    1671             elif np.ndim(value) == 2:
# -> 1672                 self._setitem_with_indexer_2d_value(indexer, value)
#    1673
#    1674             elif len(ilocs) == 1 and lplane_indexer == len(value) and not is_scalar(pi):
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_2d_value(self, indexer, value)
#    1736         for i, loc in enumerate(ilocs):
#    1737             # setting with a list, re-coerces
# -> 1738             self._setitem_single_column(loc, value[:, i].tolist(), pi)
#    1739
#    1740     def _setitem_with_indexer_frame_value(self, indexer, value: "DataFrame", name: str):
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    1815
#    1816         # reset the sliced object if unique
# -> 1817         self.obj._iset_item(loc, ser)
#    1818
#    1819     def _setitem_single_block(self, indexer, value, name: str):
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/frame.py in _iset_item(self, loc, value)
#    3220         # technically _sanitize_column expects a label, not a position,
#    3221         #  but the behavior is the same as long as we pass broadcast=False
# -> 3222         value = self._sanitize_column(loc, value, broadcast=False)
#    3223         NDFrame._iset_item(self, loc, value)
#    3224
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
# -> 3902                     value = maybe_convert_platform(value)
#    3903                 else:
#    3904                     value = com.asarray_tuplesafe(value)
#
# ~/opt/miniconda3/envs/sci/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_convert_platform(values)
#     114         if hasattr(values, "_values"):
#     115             values = values._values
# --> 116         values = lib.maybe_convert_objects(values)
#     117
#     118     return values
#
# KeyboardInterrupt:

# %% [markdown]
# # Fixed adaptation timescale

# %%
TAU_A = 5
SAVE_DIR_MA = f'data/simple/mlv/ma_alt/baker_ma_tau_a_{TAU_A}'
SAVE_PFX_MA = f'mlv_baker_ma_tau_a_{TAU_A}'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['TAU_A'] = TAU_A
df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R  TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615      5 -4.958290 -2.597432
# 1       True  0.117647  0.025128  3.835468      5 -4.163967 -1.472075
# 2       True -0.000000  0.055962  6.017162      5 -6.248007 -2.095952
# 3       True -0.000000 -0.014227  6.016828      5 -5.679735 -2.118245
# 4       True -0.000000  0.019831  6.434825      5 -4.415761 -2.863647
# ..       ...       ...       ...       ...    ...       ...       ...
# 219     True -0.000000  0.039119  1.799608      5 -0.049828  2.494657
# 220     True -0.000000 -0.001886  1.298841      5  0.098451  2.457383
# 221     True -0.588235 -0.014702  4.151226      5  8.332263  2.353217
# 222     True  0.235294 -0.095665  5.924070      5  2.390705  0.604586
# 223     True -0.000000 -0.000413  3.664384      5  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Stim-invariant adaptation

# %%
# define smln & obj function
def smlt_sia(i_s, i_p, tau_r, tau_a, x_s, x_p):
    """Simulate response to song inputs."""
    t = np.arange(len(i_s))*DT
    r = np.nan*np.zeros(len(t))
    
    r[0] = 0
    a = 0
    
    for ct, t_ in enumerate(t[1:], 1):
        a += ((DT/tau_a) * (-a + i_p[ct] + i_s[ct]))
        r[ct] = r[ct-1] + (DT/tau_r) * (-r[ct-1] + x_s*(1 - a)*i_s[ct] + x_p*(1 - a)*i_p[ct])
    
    return r

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_sia'
SAVE_PFX_MA = 'mlv_baker_ma_sia'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R        TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615    30.336758 -4.958290 -2.597432
# 1       True  0.117647  0.025128  3.835468    21.821295 -4.163967 -1.472075
# 2       True -0.000000  0.055962  6.017162    15.058055 -6.248007 -2.095952
# 3       True -0.000000 -0.014227  6.016828    11.820576 -5.679735 -2.118245
# 4       True -0.000000  0.019831  6.434825    55.496220 -4.415761 -2.863647
# ..       ...       ...       ...       ...          ...       ...       ...
# 219     True -0.000000  0.039119  1.799608  1440.994269 -0.049828  2.494657
# 220     True -0.000000 -0.001886  1.298841    27.643238  0.098451  2.457383
# 221     True -0.588235 -0.014702  4.151226     6.155551  8.332263  2.353217
# 222     True  0.235294 -0.095665  5.924070    90.705238  2.390705  0.604586
# 223     True -0.000000 -0.000413  3.664384    10.471628  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Max adaptation timescale

# %%
MAX_TAU_A = 1  # s

SAVE_DIR_MA = f'data/simple/mlv/ma_alt/baker_ma_max_tau_a_{MAX_TAU_A}'
SAVE_PFX_MA = f'mlv_baker_ma_max_tau_a_{MAX_TAU_A}'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
tau_a = np.array(df_ma_param['TAU_A'])
tau_a_fast = tau_a[tau_a <= MAX_TAU_A]
mslow_adapt = tau_a >= MAX_TAU_A
print(tau_a_fast)
df_ma_param['TAU_A'][mslow_adapt] = np.random.choice(tau_a_fast, mslow_adapt.sum())
df_ma_param
# Out:
# [0.64318249 0.37826713 0.38226739 0.4882192  0.49136376 0.63758011
#  0.6429382  0.71577622 0.55544906 0.57454694 1.        ]
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R     TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615  0.555449 -4.958290 -2.597432
# 1       True  0.117647  0.025128  3.835468  0.637580 -4.163967 -1.472075
# 2       True -0.000000  0.055962  6.017162  0.382267 -6.248007 -2.095952
# 3       True -0.000000 -0.014227  6.016828  0.643182 -5.679735 -2.118245
# 4       True -0.000000  0.019831  6.434825  0.555449 -4.415761 -2.863647
# ..       ...       ...       ...       ...       ...       ...       ...
# 219     True -0.000000  0.039119  1.799608  0.715776 -0.049828  2.494657
# 220     True -0.000000 -0.001886  1.298841  0.555449  0.098451  2.457383
# 221     True -0.588235 -0.014702  4.151226  1.000000  8.332263  2.353217
# 222     True  0.235294 -0.095665  5.924070  0.491364  2.390705  0.604586
# 223     True -0.000000 -0.000413  3.664384  0.378267  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Max adaptation timescale, fixed tau_r

# %%
MAX_TAU_A = 1  # s
TAU_R = 120  # s

SAVE_DIR_MA = f'data/simple/mlv/ma_alt/baker_ma_max_tau_a_{MAX_TAU_A}_tau_r_{TAU_R}'
SAVE_PFX_MA = f'mlv_baker_ma_max_tau_a_{MAX_TAU_A}_tau_r_{TAU_R}'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
tau_a = np.array(df_ma_param['TAU_A'])
tau_a_fast = tau_a[tau_a <= MAX_TAU_A]
mslow_adapt = tau_a >= MAX_TAU_A
print(tau_a_fast)
df_ma_param['TAU_A'][mslow_adapt] = np.random.choice(tau_a_fast, mslow_adapt.sum())
df_ma_param['TAU_R'] = TAU_R
df_ma_param
# Out:
# [0.64318249 0.37826713 0.38226739 0.4882192  0.49136376 0.63758011
#  0.6429382  0.71577622 0.55544906 0.57454694 1.        ]
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0  TAU_R     TAU_A       X_S       X_P
# 0       True -0.000000  0.028882    120  0.574547 -4.958290 -2.597432
# 1       True  0.117647  0.025128    120  0.382267 -4.163967 -1.472075
# 2       True -0.000000  0.055962    120  0.642938 -6.248007 -2.095952
# 3       True -0.000000 -0.014227    120  0.488219 -5.679735 -2.118245
# 4       True -0.000000  0.019831    120  0.637580 -4.415761 -2.863647
# ..       ...       ...       ...    ...       ...       ...       ...
# 219     True -0.000000  0.039119    120  0.643182 -0.049828  2.494657
# 220     True -0.000000 -0.001886    120  0.642938  0.098451  2.457383
# 221     True -0.588235 -0.014702    120  0.574547  8.332263  2.353217
# 222     True  0.235294 -0.095665    120  0.637580  2.390705  0.604586
# 223     True -0.000000 -0.000413    120  0.555449  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Max adaptation timescale, fixed tau_r, sine-selective only

# %%
MAX_TAU_A = 1  # s
TAU_R = 120  # s

SAVE_DIR_MA = f'data/simple/mlv/ma_alt/baker_ma_max_tau_a_{MAX_TAU_A}_tau_r_{TAU_R}_sine'
SAVE_PFX_MA = f'mlv_baker_ma_max_tau_a_{MAX_TAU_A}_tau_r_{TAU_R}_sine'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
tau_a = np.array(df_ma_param['TAU_A'])
tau_a_fast = tau_a[tau_a <= MAX_TAU_A]
mslow_adapt = tau_a >= MAX_TAU_A
print(tau_a_fast)
df_ma_param['TAU_A'][mslow_adapt] = np.random.choice(tau_a_fast, mslow_adapt.sum())
df_ma_param['TAU_R'] = TAU_R
df_ma_param['X_P'] = 0
df_ma_param
# Out:
# [0.64318249 0.37826713 0.38226739 0.4882192  0.49136376 0.63758011
#  0.6429382  0.71577622 0.55544906 0.57454694 1.        ]
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0  TAU_R     TAU_A       X_S  X_P
# 0       True -0.000000  0.028882    120  0.491364 -4.958290    0
# 1       True  0.117647  0.025128    120  0.574547 -4.163967    0
# 2       True -0.000000  0.055962    120  1.000000 -6.248007    0
# 3       True -0.000000 -0.014227    120  0.637580 -5.679735    0
# 4       True -0.000000  0.019831    120  0.637580 -4.415761    0
# ..       ...       ...       ...    ...       ...       ...  ...
# 219     True -0.000000  0.039119    120  0.555449 -0.049828    0
# 220     True -0.000000 -0.001886    120  0.378267  0.098451    0
# 221     True -0.588235 -0.014702    120  0.378267  8.332263    0
# 222     True  0.235294 -0.095665    120  0.574547  2.390705    0
# 223     True -0.000000 -0.000413    120  0.642938  6.416873    0
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Max adaptation timescale, fixed tau_r, pulse-selective only

# %%
MAX_TAU_A = 1  # s
TAU_R = 120  # s

SAVE_DIR_MA = f'data/simple/mlv/ma_alt/baker_ma_max_tau_a_{MAX_TAU_A}_tau_r_{TAU_R}_pulse'
SAVE_PFX_MA = f'mlv_baker_ma_max_tau_a_{MAX_TAU_A}_tau_r_{TAU_R}_pulse'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
tau_a = np.array(df_ma_param['TAU_A'])
tau_a_fast = tau_a[tau_a <= MAX_TAU_A]
mslow_adapt = tau_a >= MAX_TAU_A
print(tau_a_fast)
df_ma_param['TAU_A'][mslow_adapt] = np.random.choice(tau_a_fast, mslow_adapt.sum())
df_ma_param['TAU_R'] = TAU_R
df_ma_param['X_S'] = 0
df_ma_param
# Out:
# [0.64318249 0.37826713 0.38226739 0.4882192  0.49136376 0.63758011
#  0.6429382  0.71577622 0.55544906 0.57454694 1.        ]
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0  TAU_R     TAU_A  X_S       X_P
# 0       True -0.000000  0.028882    120  0.637580    0 -2.597432
# 1       True  0.117647  0.025128    120  0.488219    0 -1.472075
# 2       True -0.000000  0.055962    120  0.637580    0 -2.095952
# 3       True -0.000000 -0.014227    120  0.382267    0 -2.118245
# 4       True -0.000000  0.019831    120  0.378267    0 -2.863647
# ..       ...       ...       ...    ...       ...  ...       ...
# 219     True -0.000000  0.039119    120  0.555449    0  2.494657
# 220     True -0.000000 -0.001886    120  0.555449    0  2.457383
# 221     True -0.588235 -0.014702    120  1.000000    0  2.353217
# 222     True  0.235294 -0.095665    120  0.574547    0  0.604586
# 223     True -0.000000 -0.000413    120  0.378267    0  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Fixed response timescale

# %%
TAU_R = 120

SAVE_DIR_MA = f'data/simple/mlv/ma_alt/baker_ma_tau_r_{TAU_R}'
SAVE_PFX_MA = f'mlv_baker_ma_tau_r_{TAU_R}'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['TAU_R'] = TAU_R
df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0  TAU_R        TAU_A       X_S       X_P
# 0       True -0.000000  0.028882    120    30.336758 -4.958290 -2.597432
# 1       True  0.117647  0.025128    120    21.821295 -4.163967 -1.472075
# 2       True -0.000000  0.055962    120    15.058055 -6.248007 -2.095952
# 3       True -0.000000 -0.014227    120    11.820576 -5.679735 -2.118245
# 4       True -0.000000  0.019831    120    55.496220 -4.415761 -2.863647
# ..       ...       ...       ...    ...          ...       ...       ...
# 219     True -0.000000  0.039119    120  1440.994269 -0.049828  2.494657
# 220     True -0.000000 -0.001886    120    27.643238  0.098451  2.457383
# 221     True -0.588235 -0.014702    120     6.155551  8.332263  2.353217
# 222     True  0.235294 -0.095665    120    90.705238  2.390705  0.604586
# 223     True -0.000000 -0.000413    120    10.471628  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Fixed response timescale, no adaptation

# %%
TAU_R = 60

SAVE_DIR_MA = f'data/simple/mlv/ma_alt/baker_ma_nonadapt_tau_r_{TAU_R}'
SAVE_PFX_MA = f'mlv_baker_ma_nonadapt_tau_r_{TAU_R}'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['TAU_R'] = TAU_R
df_ma_param['TAU_A'] = np.inf
df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0  TAU_R  TAU_A       X_S       X_P
# 0       True -0.000000  0.028882     60    inf -4.958290 -2.597432
# 1       True  0.117647  0.025128     60    inf -4.163967 -1.472075
# 2       True -0.000000  0.055962     60    inf -6.248007 -2.095952
# 3       True -0.000000 -0.014227     60    inf -5.679735 -2.118245
# 4       True -0.000000  0.019831     60    inf -4.415761 -2.863647
# ..       ...       ...       ...    ...    ...       ...       ...
# 219     True -0.000000  0.039119     60    inf -0.049828  2.494657
# 220     True -0.000000 -0.001886     60    inf  0.098451  2.457383
# 221     True -0.588235 -0.014702     60    inf  8.332263  2.353217
# 222     True  0.235294 -0.095665     60    inf  2.390705  0.604586
# 223     True -0.000000 -0.000413     60    inf  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # No selectivity

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_non_select'
SAVE_PFX_MA = 'mlv_baker_ma_non_select'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
mn_selectivity = np.mean(np.array(df_ma_param[['X_S', 'X_P']]), axis=1)
df_ma_param['X_S'] = mn_selectivity
df_ma_param['X_P'] = mn_selectivity
df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R        TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615    30.336758 -3.777861 -3.777861
# 1       True  0.117647  0.025128  3.835468    21.821295 -2.818021 -2.818021
# 2       True -0.000000  0.055962  6.017162    15.058055 -4.171979 -4.171979
# 3       True -0.000000 -0.014227  6.016828    11.820576 -3.898990 -3.898990
# 4       True -0.000000  0.019831  6.434825    55.496220 -3.639704 -3.639704
# ..       ...       ...       ...       ...          ...       ...       ...
# 219     True -0.000000  0.039119  1.799608  1440.994269  1.222414  1.222414
# 220     True -0.000000 -0.001886  1.298841    27.643238  1.277917  1.277917
# 221     True -0.588235 -0.014702  4.151226     6.155551  5.342740  5.342740
# 222     True  0.235294 -0.095665  5.924070    90.705238  1.497645  1.497645
# 223     True -0.000000 -0.000413  3.664384    10.471628  3.718984  3.718984
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Pure selectivity

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_pure_select'
SAVE_PFX_MA = 'mlv_baker_ma_pure_select'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
ms_selective = np.abs(df_ma_param['X_S']) > np.abs(df_ma_param['X_P'])
mp_selective = np.abs(df_ma_param['X_P']) > np.abs(df_ma_param['X_S'])
df_ma_param['X_S'][mp_selective] = 0
df_ma_param['X_P'][ms_selective] = 0

df_ma_param

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Depolarizing responses only

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_dep_only'
SAVE_PFX_MA = 'mlv_baker_ma_dep_only'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['X_S'][df_ma_param['X_S'] < 0] = 0
df_ma_param['X_P'][df_ma_param['X_P'] < 0] = 0

df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R        TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615    30.336758  0.000000  0.000000
# 1       True  0.117647  0.025128  3.835468    21.821295  0.000000  0.000000
# 2       True -0.000000  0.055962  6.017162    15.058055  0.000000  0.000000
# 3       True -0.000000 -0.014227  6.016828    11.820576  0.000000  0.000000
# 4       True -0.000000  0.019831  6.434825    55.496220  0.000000  0.000000
# ..       ...       ...       ...       ...          ...       ...       ...
# 219     True -0.000000  0.039119  1.799608  1440.994269  0.000000  2.494657
# 220     True -0.000000 -0.001886  1.298841    27.643238  0.098451  2.457383
# 221     True -0.588235 -0.014702  4.151226     6.155551  8.332263  2.353217
# 222     True  0.235294 -0.095665  5.924070    90.705238  2.390705  0.604586
# 223     True -0.000000 -0.000413  3.664384    10.471628  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Hyperpolarizing responses only

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_hyp_only'
SAVE_PFX_MA = 'mlv_baker_ma_hyp_only'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['X_S'][df_ma_param['X_S'] > 0] = 0
df_ma_param['X_P'][df_ma_param['X_P'] > 0] = 0

df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R        TAU_A       X_S       X_P
# 0       True -0.000000  0.028882  6.202615    30.336758  0.000000  0.000000
# 1       True  0.117647  0.025128  3.835468    21.821295  0.000000  0.000000
# 2       True -0.000000  0.055962  6.017162    15.058055  0.000000  0.000000
# 3       True -0.000000 -0.014227  6.016828    11.820576  0.000000  0.000000
# 4       True -0.000000  0.019831  6.434825    55.496220  0.000000  0.000000
# ..       ...       ...       ...       ...          ...       ...       ...
# 219     True -0.000000  0.039119  1.799608  1440.994269  0.000000  2.494657
# 220     True -0.000000 -0.001886  1.298841    27.643238  0.098451  2.457383
# 221     True -0.588235 -0.014702  4.151226     6.155551  8.332263  2.353217
# 222     True  0.235294 -0.095665  5.924070    90.705238  2.390705  0.604586
# 223     True -0.000000 -0.000413  3.664384    10.471628  6.416873  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Only sine selectivity

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_sine_select'
SAVE_PFX_MA = 'mlv_baker_ma_sine_select'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['X_P'] = 0

df_ma_param

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................

# %% [markdown]
# # Only pulse selectivity

# %%
SAVE_DIR_MA = 'data/simple/mlv/ma_alt/baker_ma_pulse_select'
SAVE_PFX_MA = 'mlv_baker_ma_pulse_select'

if not os.path.exists(SAVE_DIR_MA):
    os.makedirs(SAVE_DIR_MA)

# neural response fits from Baker data
df_ma_param = pd.read_csv('data/simple/neur/baker_ma_fit_param.csv')
df_ma_param['X_S'] = 0

df_ma_param
# Out:
#      EXPT_ID        LINE  FLY                   ROI  ROI_USED   FIT_ERR  \
# 0          0      R70G01    0                 somas     False  0.275200
# 1          1      R70G01    1                 somas     False  0.186212
# 2          2      R70G01    2                 somas     False  0.248414
# 3          3      R70G01    3                 somas     False  0.455963
# 4          4      R70G01    4                 somas     False  0.229018
# ..       ...         ...  ...                   ...       ...       ...
# 219      219     VT34811    0                 somas     False  0.276087
# 220      220     VT34811    0  ascending projection     False  0.037801
# 221      221  vPN1_split    0                 somas     False  0.404112
# 222      222  vPN1_split    1                 somas     False  1.205977
# 223      223  vPN1_split    2                 somas     False  0.096240
#
#      SUCCESS       T_0       R_0     TAU_R        TAU_A  X_S       X_P
# 0       True -0.000000  0.028882  6.202615    30.336758    0 -2.597432
# 1       True  0.117647  0.025128  3.835468    21.821295    0 -1.472075
# 2       True -0.000000  0.055962  6.017162    15.058055    0 -2.095952
# 3       True -0.000000 -0.014227  6.016828    11.820576    0 -2.118245
# 4       True -0.000000  0.019831  6.434825    55.496220    0 -2.863647
# ..       ...       ...       ...       ...          ...  ...       ...
# 219     True -0.000000  0.039119  1.799608  1440.994269    0  2.494657
# 220     True -0.000000 -0.001886  1.298841    27.643238    0  2.457383
# 221     True -0.588235 -0.014702  4.151226     6.155551    0  2.353217
# 222     True  0.235294 -0.095665  5.924070    90.705238    0  0.604586
# 223     True -0.000000 -0.000413  3.664384    10.471628    0  1.021095
#
# [224 rows x 13 columns]

# %%
expt_ids = df_ma_param['EXPT_ID']

# get parameters
tau_rs = np.array(df_ma_param['TAU_R'])
tau_as = np.array(df_ma_param['TAU_A'])
x_ss = np.array(df_ma_param['X_S'])
x_ps = np.array(df_ma_param['X_P'])

# %%
# compute surrogate linear neural responses for each trial
for ctr, df_tr in enumerate(dfs_tr):
    df_tr_nrl_ma = df_tr.copy()
    sys.stdout.write('.')
    
    i_s = np.array(df_tr['S']).astype(float)
    i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
    
    # simulate ppln response
    rs = smlt_ppln_ma(i_s, i_p, tau_rs, tau_as, x_ss, x_ps, DT)
        
    df_tr_nrl_ma[[f'R_{expt_id}' for expt_id in expt_ids]] = rs
        
    np.save(os.path.join(SAVE_DIR_MA, f'{SAVE_PFX_MA}_tr_{ctr}.npy'), np.array([{'df': df_tr_nrl_ma}]))
# Out:
# ....................................................................................................................................................................................................................................................................................
