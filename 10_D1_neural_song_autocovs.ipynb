# %% [markdown]
# # Plot autocovs of song-evoked NA trajectories

# %%
# %matplotlib inline
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from scipy import signal, stats
from sklearn import decomposition, linear_model
import sys
import warnings; warnings.filterwarnings("ignore")

from aux import get_seg, rand_string
from disp import set_plot, plot_b, colors
from my_stats import nanpearsonr

cc = np.concatenate

FPS = 30.03  # sampling rate of behavioral data
DT = 1/FPS

# %%
STRAINS = ['NM91', 'ZH23']
FSTRAIN = 'data/simple/strains.csv'

MSTRAINS = [(pd.read_csv(FSTRAIN)['STRAIN'] == strain) for strain in STRAINS]
MSTRAIN = np.any(MSTRAINS, axis=0)
ISTRAIN = MSTRAIN.nonzero()[0]

NTR = MSTRAIN.sum()

# %%
# load natural songs
df_song = pd.read_csv('data/simple/c_song_f_behav.csv')[['ID', 'T', 'Q', 'S', 'P' ,'F']]
sngs_full = []
for itr in ISTRAIN:
    df_tr = df_song[df_song['ID'] == itr]
    sng_full = np.zeros(len(df_tr), dtype=int)
    sng_full[df_tr['S'] == 1] = 1
    sng_full[(df_tr['P'] == 1) | (df_tr['F'] == 1)] = 2
    sngs_full.append(sng_full)

# %%
N = 20
tau_r = np.random.uniform(120, 120, N)
tau_a = np.random.uniform(.1, 2, N)
x_s = np.random.uniform(0, 1, N)
x_p = np.random.uniform(0, 1, N)

# %%
def smlt(i_s, i_p, tau_r, tau_a, x_s, x_p):
    t = np.arange(len(i_s))*DT
    n = len(tau_a)
    
    vs = np.nan*np.zeros((len(t), n))
    vs[0, :] = 0
    
    rs = np.nan*np.zeros((len(t), n))
    rs[0, :] = 0
    
    a_ss = np.zeros((len(t), n))
    a_ps = np.zeros((len(t), n))
    
    for ct in range(1, len(t)):
        
        # update adapted input
        vs[ct, :] = x_s*(1-a_ss[ct-1, :])*i_s[ct] + x_p*(1-a_ps[ct-1, :])*i_p[ct]
        
        # update integrated response
        rs[ct, :] = rs[ct-1, :] + (DT/tau_r)*(-rs[ct-1, :] + vs[ct, :])
        
        # update adaptation variables
        a_ss[ct, :] = a_ss[ct-1, :] + (DT/tau_a)*(-a_ss[ct-1, :] + i_s[ct])
        a_ps[ct, :] = a_ps[ct-1, :] + (DT/tau_a)*(-a_ps[ct-1, :] + i_p[ct])
        
    return rs, vs, a_ss, a_ps, t

# %%
# get snippets
NTR = 30
T_SNPS = range(1, 320, 8)  # snippet lengths to fetch

ds = np.nan*np.zeros((len(T_SNPS), NTR))  # pairwise distances between neural song snippet representations

durs = []
masses = []

rs_final = []
rs_final_scrambled = []

# save some example snippets and responses
snp_xpls = []
snp_xpl_scrambleds = []

rs_full_xpl = []
rs_full_xpl_scrambled = []


for cT_SNP, T_SNP in enumerate(T_SNPS):
    sys.stdout.write(f'T_SNP {T_SNP}: ')
    
    NT_SNP = int(round(T_SNP*FPS))
    t_snp = np.arange(NT_SNP)*DT

    snps = []

    for csng, sng_full in enumerate(sngs_full):
        
        segs, bds = get_seg(sng_full > 0, min_gap=NT_SNP)
        segs = [sng_full[lb:ub] for lb, ub in bds]
        
        # keep fixed-length portions only of sufficiently long segments
        segs = [seg[:NT_SNP] for seg in segs if (len(seg) >= NT_SNP)]
        
        snps.extend(segs)

    snps_scrambled = [snp[np.random.permutation(len(snp))] for snp in snps]
    
    snps = np.array(snps)
    nsnp = len(snps)
    
    snps_scrambled = np.array(snps_scrambled)

    sys.stdout.write(f'{nsnp} snippets')

    for ctr in range(NTR):
        sys.stdout.write('.')
        isnps = np.random.choice(range(len(snps)), 2, replace=False)
        r_pair = []

        for isnp in isnps:
            # get neural response
            snp = snps[isnp]
            i_s = (snp == 1).astype(float)
            i_p = (snp == 2).astype(float)

            t_snp = np.arange(len(snp))*DT

            rs = smlt(i_s, i_p, tau_r, tau_a, x_s, x_p)[0]

            r_pair.append(rs[-1, :])
            
            rs_final.append(rs[-1, :])
            
            durs.append(T_SNP)
            masses.append(np.sum(snp > 0)*DT)
            
            # get neural response to scrambled snippet
            snp_scrambled = snps_scrambled[isnp]
            
            i_s_scrambled = (snp_scrambled == 1).astype(float)
            i_p_scrambled = (snp_scrambled == 2).astype(float)
            
            rs_scrambled = smlt(i_s_scrambled, i_p_scrambled, tau_r, tau_a, x_s, x_p)[0]
            
            rs_final_scrambled.append(rs_scrambled[-1, :])
            
            if np.random.rand() < .1:  # randomly save some examples
                snp_xpls.append(snp.copy())
                rs_full_xpl.append(rs.copy())
                
                snp_xpl_scrambleds.append(snp_scrambled.copy())
                rs_full_xpl_scrambled.append(rs_scrambled.copy())
                

        d = np.linalg.norm(r_pair[0] - r_pair[1])
        
        ds[cT_SNP, ctr] = d
    print('')
    
durs = np.array(durs)
masses = np.array(masses)
# Out:
# T_SNP 1: 4272 snippets..............................
# T_SNP 9: 436 snippets..............................
# T_SNP 17: 177 snippets..............................
# T_SNP 25: 125 snippets..............................
# T_SNP 33: 104 snippets..............................
# T_SNP 41: 95 snippets..............................
# T_SNP 49: 93 snippets..............................
# T_SNP 57: 92 snippets..............................
# T_SNP 65: 90 snippets..............................
# T_SNP 73: 88 snippets..............................
# T_SNP 81: 86 snippets..............................
# T_SNP 89: 83 snippets..............................
# T_SNP 97: 81 snippets..............................
# T_SNP 105: 81 snippets..............................
# T_SNP 113: 79 snippets..............................
# T_SNP 121: 77 snippets..............................
# T_SNP 129: 76 snippets..............................
# T_SNP 137: 75 snippets..............................
# ...

# %%
rs_final = np.array(rs_final)
pca = decomposition.PCA().fit(rs_final)
rs_final_pca = pca.transform(rs_final)

rs_final_scrambled = np.array(rs_final_scrambled)
pca_scrambled = decomposition.PCA().fit(rs_final_scrambled)
rs_final_scrambled_pca = pca_scrambled.transform(rs_final_scrambled)

fig, axs = plt.subplots(1, 3, figsize=(9, 2.5), tight_layout=True)
axs[0].scatter(1+np.arange(N), pca.explained_variance_ratio_, c='k')
axs[0].scatter(1+np.arange(N), pca_scrambled.explained_variance_ratio_, c='c')
axs[0].set_yscale('log')

set_plot(axs[0], x_label='PC #', y_label='Fraction neural\nvar. explained')

axs[1].scatter(rs_final_pca[:, 0], rs_final_pca[:, 1], c='k', s=2)
axs[1].scatter(rs_final_scrambled_pca[:, 0], rs_final_scrambled_pca[:, 1], c='c', s=2)

set_plot(axs[1], x_label='PC 1', y_label='PC 2')

axs[2].scatter(rs_final_pca[:, 2], rs_final_pca[:, 3], c='k', s=2)
axs[2].scatter(rs_final_scrambled_pca[:, 2], rs_final_scrambled_pca[:, 3], c='c', s=2)

axs[2].legend(['Natural', 'Scrambled'])

set_plot(axs[2], x_label='PC 3', y_label='PC 4')

# %%
IPCS = range(5)
ntr_plot = 50

itr_xpl_plots = np.random.choice(np.arange(len(rs_full_xpl)), ntr_plot, replace=False)

fig, axs = plt.subplots(2, 5, figsize=(15, 4.5), tight_layout=True, sharex=True)

for itr in itr_xpl_plots:
    rs = rs_full_xpl[itr]
    rs_pca = pca.transform(rs)
    
    rs_scrambled = rs_full_xpl_scrambled[itr]
    rs_scrambled_pca = pca_scrambled.transform(rs_scrambled)
    
    t_snp = np.arange(len(rs))*DT
    
    for ipc, ax_col in zip(IPCS, axs.T):
        ax_col[0].plot(t_snp, rs_pca[:, ipc], c='k', lw=.5)
        ax_col[1].plot(t_snp, rs_scrambled_pca[:, ipc], c='c', lw=.5)
        
Y_LIMS = [(-.5, .5), (-.06, .06), (-.02, .02), (-.005, .005), (-.004, .004)]
    
for cax, (y_lim, ax_col) in enumerate(zip(Y_LIMS, axs.T)):
    set_plot(ax_col[0], y_lim=y_lim, y_label='Projection', title=f'Natural (PC {IPCS[cax]+1})')
    set_plot(ax_col[1], y_lim=y_lim, x_label='Time (s)', y_label='Projection', title=f'Scrambled (PC {IPCS[cax]+1})')

# %%
from time_stats import xcov_conv_tri

T_SNP = 300

NT_SNP = int(round(T_SNP*FPS))
t = np.arange(NT_SNP)*DT

snps = []

for csng, sng_full in enumerate(sngs_full):

    segs, bds = get_seg(sng_full > 0, min_gap=NT_SNP)
    segs = [sng_full[lb:ub] for lb, ub in bds]

    # keep fixed-length portions only of sufficiently long segments
    segs = [seg[:NT_SNP] for seg in segs if (len(seg) >= NT_SNP)]

    snps.extend(segs)

snps_scrambled = [snp[np.random.permutation(len(snp))] for snp in snps]

snps = np.array(snps)
nsnp = len(snps)

snps_scrambled = np.array(snps_scrambled)

# %%
IPCS = range(4)
rs_pca_all = []
rs_scrambled_pca_all = []

for snp, snp_scrambled in zip(snps, snps_scrambled):
    sys.stdout.write('.')
    
    rs = smlt(snp==1, snp==2, tau_r, tau_a, x_s, x_p)[0]
    rs_pca = pca.transform(rs)
    rs_pca_all.append(rs_pca)
    
    rs_scrambled = smlt(snp_scrambled==1, snp_scrambled==2, tau_r, tau_a, x_s, x_p)[0]
    rs_scrambled_pca = pca_scrambled.transform(rs_scrambled)
    rs_scrambled_pca_all.append(rs_scrambled_pca)
# Out:
# .........................................................

# %%
xcovs_all = {ipc: [] for ipc in IPCS}
tcovs_all = {ipc: [] for ipc in IPCS}

xcovs_scrambled_all = {ipc: [] for ipc in IPCS}
tcovs_scrambled_all = {ipc: [] for ipc in IPCS}

for rs_pca, rs_scrambled_pca in zip(rs_pca_all, rs_scrambled_pca_all):
    sys.stdout.write('.')
    
    for ipc in IPCS:
        xcov, itcov = xcov_conv_tri(rs_pca[:, ipc], rs_pca[:, ipc])
        tcov = DT*itcov
        xcovs_all[ipc].append(xcov)
        tcovs_all[ipc].append(tcov)
    
    for ipc in IPCS:
        xcov_scrambled, itcov_scrambled = xcov_conv_tri(rs_scrambled_pca[:, ipc], rs_scrambled_pca[:, ipc])
        tcov_scrambled = DT*itcov_scrambled
        xcovs_scrambled_all[ipc].append(xcov_scrambled)
        tcovs_scrambled_all[ipc].append(tcov_scrambled)
# Out:
# .........................................................

# %%
NXPL = 20
itr_xpl_plots = np.random.choice(np.arange(len(rs_pca_all)), NXPL, replace=False)

# plot correlation functions
for ipc in IPCS:
    fig_nat, axs_nat = plt.subplots(2, 10, figsize=(15, 3), tight_layout=True, sharex=True)
    fig_scrm, axs_scrm = plt.subplots(2, 10, figsize=(15, 3), tight_layout=True, sharex=True)

    
    for citr, (itr, ax_nat, ax_scrm) in enumerate(zip(itr_xpl_plots, axs_nat.flat, axs_scrm.flat)):

        xcov = xcovs_all[ipc][itr]
        tcov = tcovs_all[ipc][itr]
        
        mt = np.abs(tcov) < np.max(tcov)/2

        ax_nat.plot(tcov[mt], xcov[mt], c='k')
        
        xcov_scrambled = xcovs_scrambled_all[ipc][itr]
        tcov_scrambled = tcovs_scrambled_all[ipc][itr]

        ax_scrm.plot(tcov_scrambled[mt], xcov_scrambled[mt], c='c')
        
    for axs in [axs_nat, axs_scrm]:
        for ax in axs[0, :]:
            set_plot(ax, title=f'PC {ipc+1}')
        for ax in axs[-1, :]:
            set_plot(ax, x_label='Time lag (s)')
            
        for ax in axs.flat:
            ax.axhline(0, color='gray', ls='--')
            set_plot(ax, y_ticks=[])
            
        for ax in axs[:, 0]:
            set_plot(ax, y_label='Autocov.')

    fig_nat.savefig(f'ms/fig_5_autocovs_nat_pc_{ipc+1}.svg')
    fig_scrm.savefig(f'ms/fig_5_autocovs_scrm_pc_{ipc+1}.svg')
    
    mt_log_log = (tcov > 0) & mt
    
    fig, axs = plt.subplots(1, 4, figsize=(12, 3), tight_layout=True)
    xcov_mn = np.mean(xcovs_all[ipc], axis=0)
    axs[0].plot(tcovs_all[ipc][0][mt], xcov_mn[mt], c='k')
    set_plot(axs[0], x_label='Time lag (s)', y_label='Autocov', title=f'PC {ipc}')
    axs[1].loglog(tcovs_all[ipc][0][mt_log_log], xcov_mn[mt_log_log], c='k')
    set_plot(axs[1], x_label='Time lag (s)', y_label='Autocov', title=f'PC {ipc}')
    
    xcov_mn_scrambled = np.mean(xcovs_scrambled_all[ipc], axis=0)
    axs[2].plot(tcovs_all[ipc][0][mt], xcov_mn_scrambled[mt], c='c')
    set_plot(axs[2], x_label='Time lag (s)', y_label='Autocov', title=f'PC {ipc}')

# %% [markdown]
# # Plot separation of neural song reprs as func of num top PCs removed

# %%
from disp import set_color, get_line_log

# plot traj separation over time excluding top PCs
NPC_XCLS = [0, 1, 2, 3, 5, 10]

fig, axs = plt.subplots(2, len(NPC_XCLS), figsize=(16, 5), tight_layout=True)

for cNPC_XCL, NPC_XCL in enumerate(NPC_XCLS):

    rs_xcl = np.nan*np.zeros((len(rs_pca_all), len(t), N-NPC_XCL))

    for crs_pca, rs_pca in enumerate(rs_pca_all):
        rs_xcl[crs_pca, :, :] = rs_pca[:, NPC_XCL:]
        
    N_SEG_PLOT = 30
    rs_xcl_mn = rs_xcl.mean(axis=0)
    rs_xcl_mn_zero = rs_xcl - rs_xcl_mn

    fig_detailed, axs_detailed = plt.subplots(2, 4, figsize=(12, 5), tight_layout=True)
    for cseg in range(N_SEG_PLOT):
        for cax, ax in enumerate(axs_detailed[0, :]):
            ax.plot(t, rs_xcl[cseg, :, cax])

    for cax, ax in enumerate(axs_detailed[0, :]):
        ax.plot(t, rs_xcl_mn[:, cax], c='k', lw=4)
        set_plot(ax, x_label='Time (s)', y_label='r', title=f'Original\n(top {NPC_XCL} PCs excluded)')

    for cseg in range(N_SEG_PLOT):
        for cax, ax in enumerate(axs_detailed[1, :]):
            ax.plot(t, rs_xcl_mn_zero[cseg, :, cax])

    for cax, ax in enumerate(axs_detailed[1, :]):
        set_plot(ax, x_label='Time (s)', y_label='r', title=f'Mean subtracted\n(top {NPC_XCL} PCs excluded)')
        
        
    # compute rms displacement of zero-mean trajectories
    rmsds = np.nan*np.zeros((len(rs_xcl), len(t)))

    for cseg in range(len(rs_xcl)):
        rmsds[cseg, :] = np.linalg.norm(rs_xcl_mn_zero[cseg, :, :], axis=1)

    mt = np.round(np.logspace(0, np.log10(len(t)-1), 10)).astype(int)
    axs[1, cNPC_XCL].errorbar(t[mt], rmsds.mean(0)[mt], yerr=np.std(rmsds, axis=0)[mt], c='k')

    x_ln, y_ln, (slp, icpt, r, p, sterr) = get_line_log(t[t>0], rmsds.mean(0)[t>0])

    axs[1, cNPC_XCL].plot(10**x_ln, 10**y_ln, c='r')
    axs[1, cNPC_XCL].set_xscale('log')
    axs[1, cNPC_XCL].set_yscale('log')

    set_plot(axs[1, cNPC_XCL], x_label='Elapsed time (s)', title=f'{NPC_XCL} PCs excluded\nslope = {slp:.4f}')
    if cNPC_XCL < 2:
        set_plot(axs[1, cNPC_XCL], y_label='Dist from\norigin')
    
    
    # song separation
    NPAIR = 50

    ds = np.nan*np.zeros((NPAIR, len(t)))
    for cpair in range(NPAIR):
        idx_0, idx_1 = np.random.choice(np.arange(len(rs_xcl)), 2, replace=False)
        ds[cpair, :] = np.linalg.norm(rs_xcl[idx_0, :, :]-rs_xcl[idx_1, :, :], axis=1)
    
    axs[0, cNPC_XCL].errorbar(t[mt], ds.mean(0)[mt], yerr=np.std(ds, axis=0)[mt], c='k')

    x_ln, y_ln, (slp, icpt, r, p, sterr) = get_line_log(t[t>0], ds.mean(0)[t>0])

    axs[0, cNPC_XCL].plot(10**x_ln, 10**y_ln, c='r', lw=2)
    axs[0, cNPC_XCL].set_xscale('log')
    axs[0, cNPC_XCL].set_yscale('log')

    set_plot(axs[0, cNPC_XCL], x_label='Elapsed time (s)', title=f'{NPC_XCL} PCs excluded\nslope = {slp:.4f}')
    if cNPC_XCL < 2:
        set_plot(axs[0, cNPC_XCL], y_label='Neural distance')
        
fig.savefig('ms/fig_5_neural_separation_vs_pcs_excluded.svg')
