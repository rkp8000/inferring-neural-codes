# %% [markdown]
# # Greedily construct the neural population that explains the most MTN variance

# %%
# %matplotlib inline
from itertools import product as cproduct
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys

from disp import set_plot

from record_0_main import smlt_ma
from my_torch import skl_fit_lin_single, skl_fit_ridge_add_col

cc = np.concatenate

FPS = 30.03  # sampling rate of behavioral data
DT = 1/FPS

STRAINS = ['NM91', 'ZH23']
STRAIN_KEY = '_'.join(STRAINS).lower()

PTRAIN = .8
NSPLIT = 30

TARG_BHV = 'MTN'
TWDWS = [.03, 1, 60]
TARGS = [f'{TARG_BHV}_MN_{twdw}' for twdw in TWDWS]

ALPHA = 10

# %%
PFX_BHV = f'data/simple/behav_xtd/behav_xtd'
PFX_NRL = f'data/simple/mlv/ma_red_greedy/nrl/ma_red_greedy_nrl'

MASK_PFX = f'data/simple/masks/mask'

FSTRAIN = 'data/simple/strains.csv'
MSTRAINS = [(pd.read_csv(FSTRAIN)['STRAIN'] == strain) for strain in STRAINS]
MSTRAIN = np.any(MSTRAINS, axis=0)
ISTRAIN = MSTRAIN.nonzero()[0]

NTR = len(ISTRAIN)
NTRAIN = int(round(PTRAIN*NTR))

# %% [markdown]
# Load behavioral data from Coen et al 2014

# %%
df_behav = pd.read_csv('data/simple/c_song_f_behav.csv')
df_behav
# Out:
#           ID  FRAME           T  Q  S  P  F    FFV     FFA    FLS    FRS  \
# 0          0      0    0.000000  1  0  0  0  0.231  0.0000  0.159  0.077
# 1          0      1    0.033300  1  0  0  0  0.314  0.0385  0.025  0.044
# 2          0      2    0.066600  1  0  0  0  0.308  0.0025  0.029  0.011
# 3          0      3    0.099900  1  0  0  0  0.319  0.0020  0.016  0.016
# 4          0      4    0.133200  1  0  0  0  0.312 -0.0315  0.030  0.002
# ...      ...    ...         ... .. .. .. ..    ...     ...    ...    ...
# 4978565  275  27100  902.430902  1  0  0  0  0.217  0.0280  0.029  0.058
# 4978566  275  27101  902.464202  1  0  0  0  0.210 -0.1045  0.138  0.322
# 4978567  275  27102  902.497502  1  0  0  0  0.008 -0.0910  0.034  0.260
# 4978568  275  27103  902.530803  1  0  0  0  0.028  0.0695  0.010  0.090
# 4978569  275  27104  902.564103  1  0  0  0  0.147  0.0000  0.065  0.001
#
#              FMFV      FMLS
# 0       -0.058526  0.274257
# 1        0.100623  0.298490
# 2        0.147629  0.271865
# 3        0.091174  0.306112
# 4        0.065871  0.306439
# ...           ...       ...
# 4978565 -0.171418  0.136184
# 4978566  0.032522  0.249171
# 4978567  0.033202  0.010844
# 4978568  0.012059  0.027177
# 4978569  0.089547  0.133474
#
# [4978570 rows x 13 columns]

# %%
# split big df into dfs for individual trials
n_tr = np.max(df_behav.ID) + 1
dfs_tr = [df_behav[df_behav.ID == i] for i in ISTRAIN]

df_behav = None

# %% [markdown]
# ## Define complete neural population

# %%
TAU_R = np.array([.1, .5, 1, 2, 5, 10, 30, 60, 120])
TAU_A = np.array([.1, .5, 1, 2, 5, 10, 30, 60, np.inf])
X_S = np.array([0, .5, 1])

tau_r_tau_a_x_s = np.array(list(cproduct(TAU_R, TAU_A, X_S)))

tau_rs = tau_r_tau_a_x_s[:, 0]
tau_as = tau_r_tau_a_x_s[:, 1]
x_ss = tau_r_tau_a_x_s[:, 2]
x_ps = 1 - x_ss  # pulse selectivity

n = len(tau_rs)
r_cols = [f'R_{cr}' for cr in range(n)]

# %% [markdown]
# ## Simulate population recordings

# %% [raw]
# # record data
# for itr, df_tr in zip(ISTRAIN, dfs_tr):
#     sys.stdout.write('.')
#
#     df_tr_nrl = df_tr.copy()
#
#     i_s = np.array(df_tr['S']).astype(float)
#     i_p = np.array(df_tr['P'] | df_tr['F']).astype(float)
#
#     # simulate population response
#     params = {'TAU_R': tau_rs, 'TAU_A': tau_as, 'X_S': x_ss, 'X_P': x_ps}
#     rs = smlt_ma(i_s, i_p, params, DT)
#
#     df_tr_nrl[r_cols] = rs
#
#     np.save(f'{PFX_NRL}_tr_{itr}.npy', np.array([{'df': df_tr_nrl}]))

# %% [markdown]
# ## Iteratively and greedily add next best neuron to MTN predictor set

# %% [raw]
# N_MAX = 50
#
# nrns_greedy = {targ: [] for targ in TARGS}
#
# r2_train_greedy = {targ: [] for targ in TARGS}
# r2_test_greedy = {targ: [] for targ in TARGS}
#
# for citer in range(N_MAX):
#
#     if citer == 0:
#         rslt = skl_fit_lin_single(
#             pfxs=[PFX_NRL, PFX_BHV],
#             cols_x=r_cols,
#             targs=TARGS,
#             itr_all=ISTRAIN,
#             ntrain=NTRAIN,
#             nsplit=NSPLIT,
#             mask_pfx=MASK_PFX,
#             verbose=False)
#
#     else:
#         cols_x_fixed = {
#             targ: [f'R_{inrn}' for inrn in nrns_greedy[targ]]
#             for targ in TARGS
#         }
#
#         rslt = skl_fit_ridge_add_col(
#             pfxs=[PFX_NRL, PFX_BHV],
#             cols_x=r_cols,
#             cols_x_fixed=cols_x_fixed,
#             targs=TARGS,
#             itr_all=ISTRAIN,
#             ntrain=NTRAIN,
#             nsplit=NSPLIT,
#             alpha=ALPHA,
#             mask_pfx=MASK_PFX,
#             verbose=False)
#
#     for targ in TARGS:
#         r2_train_mn = rslt.r2_train[targ].mean(axis=0)  # avg over splits
#         r2_test_mn = rslt.r2_test[targ].mean(axis=0)
#
#         nrns_greedy[targ].append(np.argmax(r2_test_mn))
#
#         r2_train_greedy[targ].append(np.max(r2_train_mn))
#         r2_test_greedy[targ].append(np.max(r2_test_mn))
#
#     # save results
#     np.save(f'data/simple/mlv/ma_red_greedy/ma_red_greedy_max_{N_MAX}.npy', np.array([
#         {'nrns_greedy': nrns_greedy, 'r2_train_greedy': r2_train_greedy, 'r2_test_greedy': r2_test_greedy}
#     ]))

# %% [markdown]
# ## Plot variance explained vs # neurons for each target

# %%
load_data = np.load('data/simple/mlv/ma_red_greedy/ma_red_greedy_max_50.npy', allow_pickle=True)[0]

r2_train_greedy = load_data['r2_train_greedy']
r2_test_greedy = load_data['r2_test_greedy']

fig, axs = plt.subplots(1, 3, figsize=(15, 4), tight_layout=True)
for ax, targ in zip(axs, TARGS):
    ax.plot(np.arange(len(r2_train_greedy[targ]) + 1), cc([[0], r2_train_greedy[targ]]), lw=2)
    ax.plot(np.arange(len(r2_test_greedy[targ]) + 1), cc([[0], r2_test_greedy[targ]]), lw=2)
    if ax is axs[0]:
        ax.legend(['Train', 'Test'])
    set_plot(ax, x_label='# neurons', y_label='R2', title=targ, font_size=14)
    
    ax.grid()

# %%
# nicer version for manuscript plot
load_data = np.load('data/simple/mlv/ma_red_greedy/ma_red_greedy_max_50.npy', allow_pickle=True)[0]

r2_train_greedy = load_data['r2_train_greedy']
r2_test_greedy = load_data['r2_test_greedy']

fig, axs = plt.subplots(1, 3, figsize=(9, 2.75), tight_layout=True)
for ax, targ in zip(axs, TARGS):
    ax.plot(np.arange(len(r2_test_greedy[targ]) + 1), 100*cc([[0], r2_test_greedy[targ]]), lw=2, c='b')
    set_plot(ax, x_label='Number of neurons', y_label=r'% walking var. expl.', font_size=14)
    
#     ax.grid()
    
fig.savefig('ms/fig_2i.svg')

# %%
# print out time constants of neurons
nrns_greedy = load_data['nrns_greedy']
for targ in TARGS:
    print('')
    print(targ)
    for cnrn, nrn in enumerate(nrns_greedy[targ]):
        r2 = r2_test_greedy[targ][cnrn]
        print(f'Neuron {cnrn+1} (R2 = {r2:.5f}): {nrn}: TAU_R = {tau_rs[nrn]:.1f}, TAU_A = {tau_as[nrn]:.1f}, X_S = {x_ss[nrn]:.2f}, X_P = {x_ps[nrn]:.2f}')
# Out:
# MTN_MN_0.03
# Neuron 1 (R2 = 0.05473): 236: TAU_R = 120.0, TAU_A = 30.0, X_S = 1.00, X_P = 0.00
# Neuron 2 (R2 = 0.09054): 135: TAU_R = 10.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 3 (R2 = 0.09660): 242: TAU_R = 120.0, TAU_A = inf, X_S = 1.00, X_P = 0.00
# Neuron 4 (R2 = 0.09845): 180: TAU_R = 30.0, TAU_A = 30.0, X_S = 0.00, X_P = 1.00
# Neuron 5 (R2 = 0.10777): 165: TAU_R = 30.0, TAU_A = 0.5, X_S = 0.00, X_P = 1.00
# Neuron 6 (R2 = 0.11231): 159: TAU_R = 10.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 7 (R2 = 0.11459): 193: TAU_R = 60.0, TAU_A = 0.5, X_S = 0.50, X_P = 0.50
# Neuron 8 (R2 = 0.11652): 19: TAU_R = 0.1, TAU_A = 30.0, X_S = 0.50, X_P = 0.50
# Neuron 9 (R2 = 0.11761): 177: TAU_R = 30.0, TAU_A = 10.0, X_S = 0.00, X_P = 1.00
# Neuron 10 (R2 = 0.11853): 25: TAU_R = 0.1, TAU_A = inf, X_S = 0.50, X_P = 0.50
# Neuron 11 (R2 = 0.11940): 162: TAU_R = 30.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 12 (R2 = 0.12017): 78: TAU_R = 1.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 13 (R2 = 0.12066): 110: TAU_R = 5.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 14 (R2 = 0.12145): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 15 (R2 = 0.12214): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 16 (R2 = 0.12268): 82: TAU_R = 2.0, TAU_A = 0.1, X_S = 0.50, X_P = 0.50
# Neuron 17 (R2 = 0.12308): 193: TAU_R = 60.0, TAU_A = 0.5, X_S = 0.50, X_P = 0.50
# Neuron 18 (R2 = 0.12341): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 19 (R2 = 0.12372): 156: TAU_R = 10.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 20 (R2 = 0.12394): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 21 (R2 = 0.12424): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 22 (R2 = 0.12444): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 23 (R2 = 0.12457): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 24 (R2 = 0.12472): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 25 (R2 = 0.12484): 159: TAU_R = 10.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 26 (R2 = 0.12496): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 27 (R2 = 0.12508): 111: TAU_R = 5.0, TAU_A = 0.5, X_S = 0.00, X_P = 1.00
# Neuron 28 (R2 = 0.12524): 186: TAU_R = 30.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 29 (R2 = 0.12537): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 30 (R2 = 0.12545): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 31 (R2 = 0.12552): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 32 (R2 = 0.12559): 21: TAU_R = 0.1, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 33 (R2 = 0.12587): 0: TAU_R = 0.1, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 34 (R2 = 0.12597): 51: TAU_R = 0.5, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 35 (R2 = 0.12622): 28: TAU_R = 0.5, TAU_A = 0.1, X_S = 0.50, X_P = 0.50
# Neuron 36 (R2 = 0.12629): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 37 (R2 = 0.12635): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 38 (R2 = 0.12640): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 39 (R2 = 0.12645): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 40 (R2 = 0.12649): 147: TAU_R = 10.0, TAU_A = 5.0, X_S = 0.00, X_P = 1.00
# Neuron 41 (R2 = 0.12656): 22: TAU_R = 0.1, TAU_A = 60.0, X_S = 0.50, X_P = 0.50
# Neuron 42 (R2 = 0.12660): 16: TAU_R = 0.1, TAU_A = 10.0, X_S = 0.50, X_P = 0.50
# Neuron 43 (R2 = 0.12664): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 44 (R2 = 0.12667): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 45 (R2 = 0.12670): 3: TAU_R = 0.1, TAU_A = 0.5, X_S = 0.00, X_P = 1.00
# Neuron 46 (R2 = 0.12680): 33: TAU_R = 0.5, TAU_A = 1.0, X_S = 0.00, X_P = 1.00
# Neuron 47 (R2 = 0.12686): 60: TAU_R = 1.0, TAU_A = 1.0, X_S = 0.00, X_P = 1.00
# Neuron 48 (R2 = 0.12689): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 49 (R2 = 0.12692): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
#
# MTN_MN_1
# Neuron 1 (R2 = 0.09022): 236: TAU_R = 120.0, TAU_A = 30.0, X_S = 1.00, X_P = 0.00
# Neuron 2 (R2 = 0.16786): 135: TAU_R = 10.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 3 (R2 = 0.18057): 242: TAU_R = 120.0, TAU_A = inf, X_S = 1.00, X_P = 0.00
# Neuron 4 (R2 = 0.18648): 180: TAU_R = 30.0, TAU_A = 30.0, X_S = 0.00, X_P = 1.00
# Neuron 5 (R2 = 0.20886): 165: TAU_R = 30.0, TAU_A = 0.5, X_S = 0.00, X_P = 1.00
# Neuron 6 (R2 = 0.21717): 159: TAU_R = 10.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 7 (R2 = 0.22224): 193: TAU_R = 60.0, TAU_A = 0.5, X_S = 0.50, X_P = 0.50
# Neuron 8 (R2 = 0.22513): 177: TAU_R = 30.0, TAU_A = 10.0, X_S = 0.00, X_P = 1.00
# Neuron 9 (R2 = 0.22712): 162: TAU_R = 30.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 10 (R2 = 0.22841): 110: TAU_R = 5.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 11 (R2 = 0.23013): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 12 (R2 = 0.23157): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 13 (R2 = 0.23296): 156: TAU_R = 10.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 14 (R2 = 0.23442): 85: TAU_R = 2.0, TAU_A = 0.5, X_S = 0.50, X_P = 0.50
# Neuron 15 (R2 = 0.23559): 13: TAU_R = 0.1, TAU_A = 5.0, X_S = 0.50, X_P = 0.50
# Neuron 16 (R2 = 0.23629): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 17 (R2 = 0.23723): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 18 (R2 = 0.23780): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 19 (R2 = 0.23836): 25: TAU_R = 0.1, TAU_A = inf, X_S = 0.50, X_P = 0.50
# Neuron 20 (R2 = 0.23912): 22: TAU_R = 0.1, TAU_A = 60.0, X_S = 0.50, X_P = 0.50
# Neuron 21 (R2 = 0.23966): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 22 (R2 = 0.24010): 38: TAU_R = 0.5, TAU_A = 2.0, X_S = 1.00, X_P = 0.00
# Neuron 23 (R2 = 0.24050): 129: TAU_R = 5.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 24 (R2 = 0.24088): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 25 (R2 = 0.24117): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 26 (R2 = 0.24144): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 27 (R2 = 0.24171): 159: TAU_R = 10.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 28 (R2 = 0.24196): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 29 (R2 = 0.24212): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 30 (R2 = 0.24230): 62: TAU_R = 1.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 31 (R2 = 0.24243): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 32 (R2 = 0.24257): 186: TAU_R = 30.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 33 (R2 = 0.24271): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 34 (R2 = 0.24286): 111: TAU_R = 5.0, TAU_A = 0.5, X_S = 0.00, X_P = 1.00
# Neuron 35 (R2 = 0.24301): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 36 (R2 = 0.24313): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 37 (R2 = 0.24327): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 38 (R2 = 0.24337): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 39 (R2 = 0.24345): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 40 (R2 = 0.24354): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 41 (R2 = 0.24360): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 42 (R2 = 0.24366): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 43 (R2 = 0.24371): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 44 (R2 = 0.24376): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 45 (R2 = 0.24381): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 46 (R2 = 0.24386): 132: TAU_R = 5.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 47 (R2 = 0.24390): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 48 (R2 = 0.24394): 0: TAU_R = 0.1, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 49 (R2 = 0.24398): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
#
# MTN_MN_60
# Neuron 1 (R2 = 0.11688): 236: TAU_R = 120.0, TAU_A = 30.0, X_S = 1.00, X_P = 0.00
# Neuron 2 (R2 = 0.19296): 162: TAU_R = 30.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 3 (R2 = 0.23738): 183: TAU_R = 30.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 4 (R2 = 0.27298): 165: TAU_R = 30.0, TAU_A = 0.5, X_S = 0.00, X_P = 1.00
# Neuron 5 (R2 = 0.28886): 215: TAU_R = 60.0, TAU_A = inf, X_S = 1.00, X_P = 0.00
# Neuron 6 (R2 = 0.29462): 159: TAU_R = 10.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 7 (R2 = 0.30007): 147: TAU_R = 10.0, TAU_A = 5.0, X_S = 0.00, X_P = 1.00
# Neuron 8 (R2 = 0.30420): 189: TAU_R = 60.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 9 (R2 = 0.30544): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 10 (R2 = 0.30767): 110: TAU_R = 5.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 11 (R2 = 0.30947): 177: TAU_R = 30.0, TAU_A = 10.0, X_S = 0.00, X_P = 1.00
# Neuron 12 (R2 = 0.31168): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 13 (R2 = 0.31416): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 14 (R2 = 0.31636): 192: TAU_R = 60.0, TAU_A = 0.5, X_S = 0.00, X_P = 1.00
# Neuron 15 (R2 = 0.31724): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 16 (R2 = 0.31804): 238: TAU_R = 120.0, TAU_A = 60.0, X_S = 0.50, X_P = 0.50
# Neuron 17 (R2 = 0.31872): 137: TAU_R = 10.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 18 (R2 = 0.31948): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 19 (R2 = 0.32009): 21: TAU_R = 0.1, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 20 (R2 = 0.32103): 108: TAU_R = 5.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 21 (R2 = 0.32153): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 22 (R2 = 0.32198): 186: TAU_R = 30.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 23 (R2 = 0.32237): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 24 (R2 = 0.32267): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 25 (R2 = 0.32292): 238: TAU_R = 120.0, TAU_A = 60.0, X_S = 0.50, X_P = 0.50
# Neuron 26 (R2 = 0.32315): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 27 (R2 = 0.32338): 164: TAU_R = 30.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 28 (R2 = 0.32377): 233: TAU_R = 120.0, TAU_A = 10.0, X_S = 1.00, X_P = 0.00
# Neuron 29 (R2 = 0.32411): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 30 (R2 = 0.32433): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 31 (R2 = 0.32455): 164: TAU_R = 30.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 32 (R2 = 0.32473): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 33 (R2 = 0.32487): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 34 (R2 = 0.32501): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 35 (R2 = 0.32513): 233: TAU_R = 120.0, TAU_A = 10.0, X_S = 1.00, X_P = 0.00
# Neuron 36 (R2 = 0.32525): 67: TAU_R = 1.0, TAU_A = 5.0, X_S = 0.50, X_P = 0.50
# Neuron 37 (R2 = 0.32546): 52: TAU_R = 0.5, TAU_A = inf, X_S = 0.50, X_P = 0.50
# Neuron 38 (R2 = 0.32560): 164: TAU_R = 30.0, TAU_A = 0.1, X_S = 1.00, X_P = 0.00
# Neuron 39 (R2 = 0.32574): 186: TAU_R = 30.0, TAU_A = inf, X_S = 0.00, X_P = 1.00
# Neuron 40 (R2 = 0.32587): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 41 (R2 = 0.32598): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00
# Neuron 42 (R2 = 0.32607): 216: TAU_R = 120.0, TAU_A = 0.1, X_S = 0.00, X_P = 1.00
# Neuron 43 (R2 = 0.32616): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 44 (R2 = 0.32631): 167: TAU_R = 30.0, TAU_A = 0.5, X_S = 1.00, X_P = 0.00
# Neuron 45 (R2 = 0.32644): 230: TAU_R = 120.0, TAU_A = 5.0, X_S = 1.00, X_P = 0.00
# Neuron 46 (R2 = 0.32659): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 47 (R2 = 0.32669): 197: TAU_R = 60.0, TAU_A = 1.0, X_S = 1.00, X_P = 0.00
# Neuron 48 (R2 = 0.32679): 167: TAU_R = 30.0, TAU_A = 0.5, X_S = 1.00, X_P = 0.00
# Neuron 49 (R2 = 0.32689): 210: TAU_R = 60.0, TAU_A = 60.0, X_S = 0.00, X_P = 1.00

# %% [markdown]
# ## Make bar charts of top neuron params

# %%
GRID = (2, 6)

TARG = 'MTN_MN_1'
fig, axs = plt.subplots(*GRID, figsize=(6.5, 2.75), tight_layout=True, sharex=True, sharey=True)
for cnrn, (nrn, ax) in enumerate(zip(nrns_greedy[TARG], axs.flat)):
    r2 = r2_test_greedy[TARG][cnrn]
    tau_r = tau_rs[nrn]
    tau_a = tau_as[nrn]
    x_s = x_ss[nrn]
    x_p = x_ps[nrn]

    ax.bar(range(2), [tau_r, tau_a], align='center', width=.8, color=['k', 'g'])
    ax_twin = ax.twinx()
    ax_twin.bar(range(2, 4), [x_s, x_p], align='center', width=.8, color=['b', 'r'])
    ax_twin.set_yticks(range(2))

    ax.set_xticks(range(4))
    
    if cnrn % GRID[1] == 0:
        ax.set_ylabel(r'$\tau$ (s)')
    if cnrn % GRID[1] == 5:
        ax_twin.set_ylabel(r'$x_s, x_p$', fontsize=10)
    else:
        ax_twin.set_yticklabels(['', ''])
    
    set_plot(
        ax, y_lim=(0, 120), x_ticks=range(4), x_tick_labels=[r'$\tau_r$', r'$\tau_a$', r'$x_s$', r'$x_p$'],
        title=f'Neuron {cnrn+1}\n' + r'$R^2 = $' + f'{r2:.3f}', font_size=10)
    
fig.savefig('ms/fig_2j.svg')
